# %% [markdown]
# # 1. What is API? How to make an API call?
# - In order to work with APIs in Python, we need tools that will make those requests.
# - Next, we need to make a ‘GET’ request, we’ll use the requests.get() function, which requires one argument — the URL we want to make the request to.

# %%
import requests

url_test = "https://numbersapi.p.rapidapi.com/6/21/date"
response = requests.get(url_test)

# %% [markdown]
# ### Check the API status code
#
# Status codes are returned with every request that is made to a web server. Status codes indicate information about what happened with a request. Here are some codes that are relevant to GET requests:
#
# 200: Everything went okay, and the result has been returned (if any).\
# 301: The server is redirecting you to a different endpoint. This can happen when a company switches domain names, or an endpoint name is changed.\
# 400: The server thinks you made a bad request. This can happen when you don’t send along the right data, among other things.\
# 401: The server thinks you’re not authenticated. Many APIs require login ccredentials, so this happens when you don’t send the right credentials to access an API.\
# 403: The resource you’re trying to access is forbidden: you don’t have the right perlessons to see it.\
# 404: The resource you tried to access wasn’t found on the server.\
# 503: The server is not ready to handle the request.\

# %%
print(response)
# Out:
# <Response [401]>

# %%
print(response.status_code)
# Out:
# 401

# %%
# Now, let's test a success API endpoint
# Get a list of universities in a specified country.

url = 'http://universities.hipolabs.com/search?country=United+States'

response = requests.get(url)

print(response.status_code)
# Out:
# 200

# %% [markdown]
# # 2. Next, read from the retrieved data
# ## We use the `response.json()` method to store the response data in a dictionary object
# - note that this only works because the result is written in JSON format – an error would have been raised otherwise.
# - [Read Here](https://requests.readthedocs.io/en/latest/user/quickstart/) for more HTTPs methods

# %%
response_json = response.json()
print(response_json)
# Out:
# [{'alpha_two_code': 'US', 'web_pages': ['http://www.marywood.edu'], 'name': 'Marywood University', 'domains': ['marywood.edu'], 'country': 'United States', 'state-province': None}, {'alpha_two_code': 'US', 'web_pages': ['http://www.lindenwood.edu/'], 'name': 'Lindenwood University', 'domains': ['lindenwood.edu'], 'country': 'United States', 'state-province': None}, {'alpha_two_code': 'US', 'web_pages': ['https://sullivan.edu/'], 'name': 'Sullivan University', 'domains': ['sullivan.edu'], 'country': 'United States', 'state-province': None}, {'alpha_two_code': 'US', 'web_pages': ['https://www.fscj.edu/'], 'name': 'Florida State College at Jacksonville', 'domains': ['fscj.edu'], 'country': 'United States', 'state-province': None}, {'alpha_two_code': 'US', 'web_pages': ['https://www.xavier.edu/'], 'name': 'Xavier University', 'domains': ['xavier.edu'], 'country': 'United States', 'state-province': None}, {'alpha_two_code': 'US', 'web_pages': ['https://home.tusculum.edu/'], 'name': 'Tusculum College', 'domains': ['tusculum.edu'], 'country': 'United States', 'state-province': None}, {'alpha_two_code': 'US', 'web_pages': ['https://cst.edu/'], 'name': 'Claremont School of Theology', 'domains': ['cst.edu'], 'country': 'United States', 'state-province': None}, {'alpha_two_code': 'US', 'web_pages': ['https://www.columbiasc.edu/'], 'name': 'Columbia College (SC)', 'domains': ['columbiasc.edu'], 'country': 'United States', 'state-province': None}, {'alpha_two_code': 'US', 'web_pages': ['http://www.clpccd.edu/'], 'name': 'Chabot-Las Positas Community College District', 'domains': ['clpccd.edu'], 'country': 'United States', 'state-province': None}, {'alpha_two_code': 'US', 'web_pages': ['https://www.keller.edu/'], 'name': 'Keller Graduate School of Management', 'domains': ['keller.edu'], 'country': 'United States', 'state-province': None}, {'alpha_two_code': 'US', 'web_pages': ['https://monroecollege.edu/'], 'name': 'Monroe College', 'domains': ['monroecollege.edu'], 'country': 'United States', 'state-province': None}, {'alpha_two_code': 'US', 'web_pages': ['https://smccd.edu/'], 'name': 'San Mateo County Community College District', 'domains': ['smccd.edu'], 'country': 'United States', 'state-province': None}, {'alpha_two_code': 'US', 'web_pages': ['http://losrios.edu/'], 'name': 'Los Rios Community College District', 'domains': ['losrios.edu'], 'country': 'United States', 'state-province': None}, {'alpha_two_code': 'US', 'web_pages': ['https://www.digipen.edu/'], 'name': 'DigiPen Institute of Technology', 'domains': ['digipen.edu'], 'country': 'United States', 'state-province': None}, {'alpha_two_code': 'US', 'web_pages': ['https://www.upmc.com/'], 'name': 'University of Pittsburgh Medical Center', 'domains': ['upmc.edu', 'upmc.com'], 'country': 'United States', 'state-province': 'Pennsylvania'}, {'alpha_two_code': 'US', 'web_pages': ['https://www.cgu.edu/'], 'name': 'Claremont Graduate University', 'domains': ['cgu.edu'], 'country': 'United States', 'state-province': None}, {'alpha_two_code': 'US', 'web_pages': ['https://www.utrgv.edu/'], 'name': 'The University of Texas at Rio Grande Valley', 'domains': ['utrgv.edu'], 'country': 'United States', 'state-province': 'Texas'}, {'alpha_two_code': 'US', 'web_pages': ['https://mountsaintvincent.edu/'], 'name': 'College of Mount Saint Vincent', 'domains': ['mountsaintvincent.edu'], 'country': 'United States', 'state-province': None}, {'alpha_two_code': 'US', 'web_pages': ['https://www.uasys.edu/'], 'name': 'University of Arkansas System eVersity', 'domains': ['uasys.edu'], 'country': 'United States', 'state-province': None}, {'alpha_two_code': 'US', 'web_pages': ['https://www.ecpi.edu/'], 'name': 'ECPI University', 'domains': ['ecpi.edu'], 'country': 'United States', 'state-province': None}, {'alpha_two_code': 'US', 'web_pages': ['https://www.umw.edu/'], 'name': 'University of Mary Washington', 'domains': ['umw.edu'], 'country': 'United States', 'state-province': None}, {'alpha_two_code': 'US',  ...

# %%
for i in response_json:
    print(i, "\n")
# Out:
# {'alpha_two_code': 'US', 'web_pages': ['http://www.marywood.edu'], 'name': 'Marywood University', 'domains': ['marywood.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.lindenwood.edu/'], 'name': 'Lindenwood University', 'domains': ['lindenwood.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['https://sullivan.edu/'], 'name': 'Sullivan University', 'domains': ['sullivan.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['https://www.fscj.edu/'], 'name': 'Florida State College at Jacksonville', 'domains': ['fscj.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['https://www.xavier.edu/'], 'name': 'Xavier University', 'domains': ['xavier.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['https://home.tusculum.edu/'], 'name': 'Tusculum College', 'domains': ['tusculum.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['https://cst.edu/'], 'name': 'Claremont School of Theology', 'domains': ['cst.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['https://www.columbiasc.edu/'], 'name': 'Columbia College (SC)', 'domains': ['columbiasc.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.clpccd.edu/'], 'name': 'Chabot-Las Positas Community College District', 'domains': ['clpccd.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['https://www.keller.edu/'], 'name': 'Keller Graduate School of Management', 'domains': ['keller.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['https://monroecollege.edu/'], 'name': 'Monroe College', 'domains': ['monroecollege.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['https://smccd.edu/'], 'name': 'San Mateo County Community College District', 'domains': ['smccd.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://losrios.edu/'], 'name': 'Los Rios Community College District', 'domains': ['losrios.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['https://www.digipen.edu/'], 'name': 'DigiPen Institute of Technology', 'domains': ['digipen.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['https://www.upmc.com/'], 'name': 'University of Pittsburgh Medical Center', 'domains': ['upmc.edu', 'upmc.com'], 'country': 'United States', 'state-province': 'Pennsylvania'}
#
# {'alpha_two_code': 'US', 'web_pages': ['https://www.cgu.edu/'], 'name': 'Claremont Graduate University', 'domains': ['cgu.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['https://www.utrgv.edu/'], 'name': 'The University of Texas at Rio Grande Valley', 'domains': ['utrgv.edu'], 'country': 'United States', 'state-province': 'Texas'}
#
# {'alpha_two_code': 'US', 'web_pages': ['https://mountsaintvincent.edu/'], 'name': 'College of Mount Saint Vincent', 'domains': ['mountsaintvincent.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['https://www.uasys.edu/'], 'name': 'University of Arkansas System eVersity', 'domains': ['uasys.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['https://www.ecpi.edu/'], 'name': 'ECPI University', 'domains': ['ecpi.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['https://www.umw.edu/'], 'name': 'University of Mary Washington', 'domains': ['umw.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['https://www.bw.edu/'], 'name': 'Baldwin Wallace University', 'domains': ['bw.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['https://www.csuci.edu/'], 'name': 'California State University Channel Islands', 'domains': ['csuci.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['https://www.brandman.edu/'], 'name': 'Brandman University', 'domains': ['brandman.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.uscga.edu/'], 'name': 'United States Coast Guard Academy', 'domains': ['uscga.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.athens.edu/'], 'name': 'Athens State University', 'domains': ['athens.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['https://scripps.edu/'], 'name': 'The Scripps Research Institute', 'domains': ['scripps.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.easternflorida.edu/'], 'name': 'Eastern Florida State College', 'domains': ['easternflorida.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www1.wne.edu/'], 'name': 'Western New England University', 'domains': ['wne.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['https://king.edu/'], 'name': 'King University', 'domains': ['king.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['https://ggc.edu/'], 'name': 'Georgia Gwinnett College', 'domains': ['ggc.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['https://www.trident.edu/'], 'name': 'Trident University', 'domains': ['trident.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['https://www.alliant.edu/'], 'name': 'Alliant International University', 'domains': ['alliant.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['https://mvsu.edu/'], 'name': 'Mississippi Valley State University', 'domains': ['mvsu.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['https://www.roosevelt.edu/'], 'name': 'Roosevelt University', 'domains': ['roosevelt.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://itt-tech.info/'], 'name': 'ITT Technical Institute', 'domains': ['itt-tech.info', 'itt-tech.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['https://iecc.edu/'], 'name': 'Illinois Eastern Community Colleges', 'domains': ['iecc.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['https://park.edu/'], 'name': 'Park University', 'domains': ['park.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://icahn.mssm.edu/'], 'name': 'Icahn School of Medicine at Mount Sinai', 'domains': ['mssm.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['https://uvu.edu/'], 'name': 'Utah Valley University', 'domains': ['uvu.edu'], 'country': 'United States', 'state-province': 'Utah'}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.wlc.edu/'], 'name': 'Wisconsin Lutheran College', 'domains': ['wlc.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.rccd.edu/'], 'name': 'Riverside Community College District', 'domains': ['rccd.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.wakehealth.edu/'], 'name': 'Wake Forest Baptist Health', 'domains': ['wakehealth.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['https://www.umb.edu/'], 'name': 'University of Massachusetts Boston', 'domains': ['umb.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['https://floridapoly.edu/'], 'name': 'Florida Polytechnic University', 'domains': ['floridapoly.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['https://wagner.edu/'], 'name': 'Wagner College', 'domains': ['wagner.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['https://www.wilmu.edu/'], 'name': 'Wilmington University', 'domains': ['wilmu.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['https://itu.edu/'], 'name': 'International Technological University', 'domains': ['itu.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['https://www.yhc.edu/'], 'name': 'Young Harris College', 'domains': ['yhc.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['https://www.findlay.edu/'], 'name': 'University of Findlay', 'domains': ['findlay.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['https://www.pcom.edu/'], 'name': 'Philadelphia College of Osteopathic Medicine', 'domains': ['pcom.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['https://www.yosemite.edu/'], 'name': 'Yosemite Community College District', 'domains': ['yosemite.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.coastalalabama.edu/'], 'name': 'Coastal Alabama Community College', 'domains': ['coastalalabama.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['https://www.pnw.edu/'], 'name': 'Purdue University Northwest', 'domains': ['pnw.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.columbiabasin.edu/'], 'name': 'Columbia Basin College', 'domains': ['columbiabasin.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['https://www.seattlecolleges.edu/'], 'name': 'Seattle Colleges', 'domains': ['seattlecolleges.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['https://www.lipscomb.edu/'], 'name': 'Lipscomb University', 'domains': ['lipscomb.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.tiffin.edu/'], 'name': 'Tiffin University', 'domains': ['tiffin.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['https://troy.edu/'], 'name': 'Troy University', 'domains': ['troy.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.42.us.org/'], 'name': '42 US', 'domains': ['student.42.us.org'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.calbaptist.edu/'], 'name': 'California Baptist University', 'domains': ['calbaptist.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.stevenson.edu/'], 'name': 'Stevenson University', 'domains': ['stevenson.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.mbl.edu/'], 'name': 'Marine Biological Laboratory', 'domains': ['mbl.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.maryville.edu/'], 'name': 'Maryville University', 'domains': ['maryville.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.aii.edu/'], 'name': 'The Art Institutes', 'domains': ['aii.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.umc.edu/'], 'name': 'University of Mississippi Medical Center', 'domains': ['umc.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.uco.edu/'], 'name': 'University of Central Oklahoma', 'domains': ['uco.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.hallmarkuniversity.edu/'], 'name': 'Hallmark University', 'domains': ['hallmarkuniversity.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.keiseruniversity.edu/'], 'name': 'Keiser University', 'domains': ['keiseruniversity.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.sjrstate.edu/'], 'name': 'St. Johns River State College', 'domains': ['sjrstate.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.irsc.edu/'], 'name': 'Indian River State College', 'domains': ['irsc.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.barnard.edu/'], 'name': 'Barnard College', 'domains': ['barnard.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.calsouthern.edu/'], 'name': 'California Southern University', 'domains': ['calsouthern.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.laverne.edu/'], 'name': 'University of La Verne', 'domains': ['laverne.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.washjeff.edu/'], 'name': 'Washington & Jefferson College', 'domains': ['washjeff.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.uopeople.edu/'], 'name': 'University of the People', 'domains': ['uopeople.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.touro.edu/'], 'name': 'Touro College', 'domains': ['touro.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.njcu.edu/'], 'name': 'New Jersey City University', 'domains': ['njcu.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.lander.edu/'], 'name': 'Lander University', 'domains': ['lander.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.sunymaritime.edu/'], 'name': 'SUNY Maritime College', 'domains': ['sunymaritime.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.lesley.edu/'], 'name': 'Lesley University', 'domains': ['lesley.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.lauruscollege.edu/'], 'name': 'Laurus College', 'domains': ['lauruscollege.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.np.edu/'], 'name': 'National Park College', 'domains': ['np.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.oc.edu/'], 'name': 'Oklahoma Christian University', 'domains': ['oc.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.sdcc.edu/'], 'name': 'San Diego Christian College', 'domains': ['sdcc.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.sans.edu/'], 'name': 'SANS Technology Institute', 'domains': ['sans.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.phsc.edu/'], 'name': 'Pasco-Hernando State College', 'domains': ['phsc.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.ncf.edu/'], 'name': 'New College of Florida', 'domains': ['ncf.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.gcu.edu/'], 'name': 'Grand Canyon University', 'domains': ['gcu.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.cshl.edu/'], 'name': 'Cold Spring Harbor Laboratory', 'domains': ['cshl.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.asurams.edu/'], 'name': 'Albany State University', 'domains': ['asurams.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.lasell.edu/'], 'name': 'Lasell College', 'domains': ['lasell.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.4cd.edu/'], 'name': 'Contra Costa Community College District', 'domains': ['4cd.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.msmary.edu/'], 'name': "Mount St. Mary's University", 'domains': ['msmary.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.robertmorris.edu/'], 'name': 'Robert Morris University Illinois', 'domains': ['robertmorris.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.nwfsc.edu/'], 'name': 'Northwest Florida State College', 'domains': ['nwfsc.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.wvwc.edu/'], 'name': 'West Virginia Wesleyan College', 'domains': ['wvwc.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.utica.edu/'], 'name': 'Utica College', 'domains': ['utica.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.ccnn.edu/'], 'name': 'Career College of Northern Nevada', 'domains': ['ccnn.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['https://www.csn.edu/'], 'name': 'College of Southern Nevada', 'domains': ['csn.edu'], 'country': 'United States', 'state-province': 'NV'}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.ung.edu/'], 'name': 'University of North Georgia', 'domains': ['ung.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.principia.edu/'], 'name': 'The Principia', 'domains': ['principia.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.lynn.edu/'], 'name': 'Lynn University', 'domains': ['lynn.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.cccs.edu/'], 'name': 'Colorado Community College System', 'domains': ['cccs.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.valenciacollege.edu/'], 'name': 'Valencia College', 'domains': ['valenciacollege.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.spcollege.edu/'], 'name': 'St. Petersburg College', 'domains': ['spcollege.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.msbcollege.edu/'], 'name': 'Globe University & Minnesota School of Business', 'domains': ['msbcollege.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.everest.edu/'], 'name': 'Everest College', 'domains': ['everest.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.swri.edu/'], 'name': 'Southwest Research Institute', 'domains': ['swri.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.apus.edu/'], 'name': 'American Public University System', 'domains': ['apus.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.fullsail.edu/'], 'name': 'Full Sail University', 'domains': ['fullsail.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.yti.edu/'], 'name': 'YTI Career Institute', 'domains': ['yti.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.dliflc.edu/'], 'name': 'Defense Language Institute Foreign Language Center', 'domains': ['dliflc.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.columbusstate.edu/'], 'name': 'Columbus State University', 'domains': ['columbusstate.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.moreheadstate.edu/'], 'name': 'Morehead State University', 'domains': ['moreheadstate.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.csuglobal.edu/'], 'name': 'Colorado State University - Global Campus', 'domains': ['csuglobal.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.ndus.edu/'], 'name': 'North Dakota University System', 'domains': ['ndus.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.uhd.edu/'], 'name': 'University of Houston-Downtown', 'domains': ['uhd.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.stratford.edu/'], 'name': 'Stratford University', 'domains': ['stratford.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.cpp.edu/'], 'name': 'California Polytechnic State University, Pomona', 'domains': ['cpp.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.baker.edu/'], 'name': 'Baker College', 'domains': ['baker.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.tcnj.edu/'], 'name': 'The College of New Jersey', 'domains': ['tcnj.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.acu.edu/'], 'name': 'Abilene Christian University', 'domains': ['acu.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.adelphi.edu/'], 'name': 'Adelphi University', 'domains': ['adelphi.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.agnesscott.edu/'], 'name': 'Agnes Scott College', 'domains': ['agnesscott.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.atc.edu/'], 'name': 'Aiken Technical College', 'domains': ['atc.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.afit.edu/'], 'name': 'Air Force Institute of Technology', 'domains': ['afit.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.aamu.edu/'], 'name': 'Alabama A&M University', 'domains': ['aamu.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.alasu.edu/'], 'name': 'Alabama State University', 'domains': ['alasu.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.alamo.edu/'], 'name': 'Alamo Colleges', 'domains': ['aloma.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.acofi.edu/'], 'name': 'Albertson College of Idaho', 'domains': ['acofi.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.albion.edu/'], 'name': 'Albion College', 'domains': ['albion.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.alfred.edu/'], 'name': 'Alfred University', 'domains': ['alfred.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.alleg.edu/'], 'name': 'Allegheny College', 'domains': ['alleg.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.allencol.edu/'], 'name': 'Allentown College of Saint Francis de Sales', 'domains': ['allencol.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.alma.edu/'], 'name': 'Alma College', 'domains': ['alma.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.alverno.edu/'], 'name': 'Alverno College', 'domains': ['alverno.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.ambassador.edu/'], 'name': 'Ambassador University', 'domains': ['ambassador.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.amercoastuniv.edu/'], 'name': 'American Coastline University', 'domains': ['amercoastuniv.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.aic.edu/'], 'name': 'American International College', 'domains': ['aic.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.american.edu/'], 'name': 'American University', 'domains': ['american.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.amherst.edu/'], 'name': 'Amherst College', 'domains': ['amherst.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.andrews.edu/'], 'name': 'Andrews University', 'domains': ['andrews.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.angelo.edu/'], 'name': 'Angelo State University', 'domains': ['angelo.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.aacc.edu/'], 'name': 'Anne Arundel Community College', 'domains': ['aacc.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.antiochne.edu/'], 'name': 'Antioch New England', 'domains': ['antiochne.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.antioch.edu/'], 'name': 'Antioch University', 'domains': ['antioch.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.antiochla.edu/'], 'name': 'Antioch University - Los Angeles', 'domains': ['antiochla.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.seattleantioch.edu/'], 'name': 'Antioch University - Seattle', 'domains': ['seattleantioch.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.appstate.edu/'], 'name': 'Appalachian State University', 'domains': ['appstate.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.aquinas.edu/'], 'name': 'Aquinas College', 'domains': ['aquinas.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.arcadia.edu/'], 'name': 'Arcadia College', 'domains': ['arcadia.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.asu.edu/'], 'name': 'Arizona State University', 'domains': ['asu.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.azwestern.edu/'], 'name': 'Arizona Western College', 'domains': ['azwestern.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.astate.edu/'], 'name': 'Arkansas State University', 'domains': ['astate.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.atu.edu/'], 'name': 'Arkansas Tech University', 'domains': ['atu.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.armstrong.edu/'], 'name': 'Armstrong State College', 'domains': ['armstrong.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.ashland.edu/'], 'name': 'Ashland University', 'domains': ['ashland.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.assumption.edu/'], 'name': 'Assumption College', 'domains': ['assumption.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.auburn.edu/'], 'name': 'Auburn University', 'domains': ['auburn.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.aum.edu/'], 'name': 'Auburn University at Montgomery', 'domains': ['aum.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.augsburg.edu/'], 'name': 'Augsburg College', 'domains': ['augsburg.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.augustana.edu/'], 'name': 'Augustana College (IL)', 'domains': ['augustana.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.augie.edu/'], 'name': 'Augustana College (SD)', 'domains': ['augie.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.augusta.edu/', 'http://www.gru.edu/'], 'name': 'Augusta University', 'domains': ['augusta.edu', 'gru.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.aurora.edu/'], 'name': 'Aurora University', 'domains': ['aurora.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.austincollege.edu/'], 'name': 'Austin College', 'domains': ['austincollege.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.austincc.edu/'], 'name': 'Austin Community College', 'domains': ['austincc.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.apsu.edu/'], 'name': 'Austin Peay State University', 'domains': ['apsu.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.averett.edu/'], 'name': 'Averett College', 'domains': ['averett.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.avila.edu/'], 'name': 'Avila College', 'domains': ['avila.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.apu.edu/'], 'name': 'Azusa Pacific University', 'domains': ['apu.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.babson.edu/'], 'name': 'Babson College', 'domains': ['babson.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.bakeru.edu/'], 'name': 'Baker University', 'domains': ['bakeru.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.bsu.edu/'], 'name': 'Ball State University', 'domains': ['bsu.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.bbc.edu/'], 'name': 'Baptist Bible College', 'domains': ['bbc.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.bard.edu/'], 'name': 'Bard College', 'domains': ['bard.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.barry.edu/'], 'name': 'Barry University', 'domains': ['barry.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.bastyr.edu/'], 'name': 'Bastyr University', 'domains': ['bastyr.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.bates.edu/'], 'name': 'Bates College', 'domains': ['bates.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.bcm.edu/'], 'name': 'Baylor College of Medicine', 'domains': ['bcm.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.baylor.edu/'], 'name': 'Baylor University', 'domains': ['baylor.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.bellevue.edu/'], 'name': 'Bellevue University', 'domains': ['bellevue.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.belmont.edu/'], 'name': 'Belmont University', 'domains': ['belmont.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.beloit.edu/'], 'name': 'Beloit College', 'domains': ['beloit.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.bemidjistate.edu/'], 'name': 'Bemidji State University', 'domains': ['bemidjistate.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.benedictine.edu/'], 'name': 'Benedictine College', 'domains': ['benedictine.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.bennington.edu/'], 'name': 'Bennington College', 'domains': ['bennington.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.bentley.edu/'], 'name': 'Bentley College', 'domains': ['bentley.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.berea.edu/'], 'name': 'Berea College', 'domains': ['berea.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.berklee.edu/'], 'name': 'Berklee College of Music', 'domains': ['berklee.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.bethanywv.edu/'], 'name': 'Bethany College', 'domains': ['bethanywv.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.bethelks.edu/'], 'name': 'Bethel College (KS)', 'domains': ['bethelks.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.bethel.edu/'], 'name': 'Bethel University', 'domains': ['bethel.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.biola.edu/'], 'name': 'Biola University', 'domains': ['biola.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.bsc.edu/'], 'name': 'Birmingham-Southern College', 'domains': ['bsc.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.bhsu.edu/'], 'name': 'Black Hills State University', 'domains': ['bhsu.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.bloomu.edu/'], 'name': 'Bloomsburg University of Pennsylvania', 'domains': ['bloomu.edu'], 'country': 'United States', 'state-province': 'Pennsylvania'}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.bluffton.edu/'], 'name': 'Bluffton College', 'domains': ['bluffton.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.bju.edu/'], 'name': 'Bob Jones University', 'domains': ['bju.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.boisestate.edu/'], 'name': 'Boise State University', 'domains': ['boisestate.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.bc.edu/'], 'name': 'Boston College', 'domains': ['bc.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.bgsp.edu/'], 'name': 'Boston Graduate School of Psychoanalysis', 'domains': ['bgsp.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.bu.edu/'], 'name': 'Boston University', 'domains': ['bu.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.bowdoin.edu/'], 'name': 'Bowdoin College', 'domains': ['bowdoin.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.bowiestate.edu/'], 'name': 'Bowie State University', 'domains': ['bowiestate.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.bgsu.edu/'], 'name': 'Bowling Green State University', 'domains': ['bgsu.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.bradley.edu/'], 'name': 'Bradley University', 'domains': ['bradley.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.brandeis.edu/'], 'name': 'Brandeis University', 'domains': ['brandeis.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.brenau.edu/'], 'name': 'Brenau University', 'domains': ['brenau.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.briar-cliff.edu/'], 'name': 'Briar Cliff College', 'domains': ['briar-cliff.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.bridgewater.edu/'], 'name': 'Bridgewater College', 'domains': ['bridgewater.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.byu.edu/'], 'name': 'Brigham Young University', 'domains': ['byu.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.byui.edu/'], 'name': 'Brigham Young University - Idaho', 'domains': ['byui.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.byuh.edu/'], 'name': 'Brigham Young University Hawaii', 'domains': ['byuh.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.broward.edu/'], 'name': 'Broward College', 'domains': ['broward.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.brown.edu/'], 'name': 'Brown University', 'domains': ['brown.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.bryant.edu/'], 'name': 'Bryant College', 'domains': ['bryant.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.brynmawr.edu/college'], 'name': 'Bryn Mawr College', 'domains': ['brynmawr.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.bucknell.edu/'], 'name': 'Bucknell University', 'domains': ['bucknell.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.bvu.edu/'], 'name': 'Buena Vista University', 'domains': ['bvu.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.butler.edu/'], 'name': 'Butler University', 'domains': ['butler.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.calcoast.edu/'], 'name': 'California Coast University', 'domains': ['calcoast.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.caltech.edu/'], 'name': 'California Institute of Technology', 'domains': ['caltech.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.callutheran.edu/'], 'name': 'California Lutheran University', 'domains': ['callutheran.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.csum.edu/'], 'name': 'California Maritime Academy', 'domains': ['csum.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.cnuas.edu/'], 'name': 'California National University', 'domains': ['cnuas.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.calpoly.edu/'], 'name': 'California Polytechnic State University, San Luis Obispo', 'domains': ['calpoly.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.csub.edu/'], 'name': 'California State University, Bakersfield', 'domains': ['csub.edu', 'csubak.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.csuchico.edu/'], 'name': 'California State University, Chico', 'domains': ['csuchico.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.csudh.edu/'], 'name': 'California State University, Dominguez Hills', 'domains': ['csudh.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.csufresno.edu/', 'http://www.fresnostate.edu/'], 'name': 'California State University, Fresno', 'domains': ['csufresno.edu', 'fresnostate.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.fullerton.edu/'], 'name': 'California State University, Fullerton', 'domains': ['fullerton.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.csuhayward.edu/'], 'name': 'California State University, Hayward', 'domains': ['csuhayward.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.csulb.edu/'], 'name': 'California State University, Long Beach', 'domains': ['csulb.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.calstatela.edu/'], 'name': 'California State University, Los Angeles', 'domains': ['calstatela.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.csumb.edu/'], 'name': 'California State University, Monterey Bay', 'domains': ['csumb.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.csun.edu/'], 'name': 'California State University, Northridge', 'domains': ['csun.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.csus.edu/'], 'name': 'California State University, Sacramento', 'domains': ['csus.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.csusb.edu/'], 'name': 'California State University, San Bernardino', 'domains': ['csusb.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.csusm.edu/'], 'name': 'California State University, San Marcos', 'domains': ['csusm.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.csustan.edu/'], 'name': 'California State University, Stanislaus', 'domains': ['csustan.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.calstate.edu/'], 'name': 'California State University System', 'domains': ['calstate.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.cup.edu/'], 'name': 'California University of Pennsylvania', 'domains': ['cup.edu'], 'country': 'United States', 'state-province': 'Pennsylvania'}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.calvin.edu/'], 'name': 'Calvin College', 'domains': ['calvin.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.cameron.edu/'], 'name': 'Cameron University', 'domains': ['cameron.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.campbellsville.edu/'], 'name': 'Campbellsville College', 'domains': ['campbellsville.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.campbell.edu/'], 'name': 'Campbell University', 'domains': ['campbell.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.canisius.edu/'], 'name': 'Canisius College', 'domains': ['canisius.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.capella.edu/', 'http://www.capellauniversity.edu/'], 'name': 'Capella University', 'domains': ['capella.edu', 'capellauniversity.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.captechu.edu/'], 'name': 'Capitol Technology University', 'domains': ['captechu.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.carleton.edu/'], 'name': 'Carleton College', 'domains': ['carleton.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.carlow.edu/'], 'name': 'Carlow College', 'domains': ['carlow.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.cmu.edu/'], 'name': 'Carnegie Mellon University', 'domains': ['cmu.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.carroll.edu/'], 'name': 'Carroll College', 'domains': ['carroll.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.carrollu.edu/'], 'name': 'Carroll University', 'domains': ['carrollu.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.cn.edu/'], 'name': 'Carson-Newman College', 'domains': ['cn.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.carthage.edu/'], 'name': 'Carthage College', 'domains': ['carthage.edu'], 'country': 'United States', 'state-province': None}
#
# ...
#
# {'alpha_two_code': 'US', 'web_pages': ['https://www.gram.edu/'], 'name': 'Grambling State University', 'domains': ['gram.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['https://www.hssu.edu/'], 'name': 'Harris-Stowe State University', 'domains': ['hssu.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['https://www.hoodseminary.edu/'], 'name': 'Hood Theological', 'domains': ['hoodseminary.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['https://htu.edu/'], 'name': 'Huston-Tillotson University', 'domains': ['htu.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['https://www.itc.edu/'], 'name': 'Interdenominational Theological Center', 'domains': ['itc.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.jarvis.edu/'], 'name': 'Jarvis Christian College', 'domains': ['jarvis.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['https://www.smithseminary.org/'], 'name': 'Johnson C Smith Theological Seminary *', 'domains': ['smithseminary.org'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['https://www.kysu.edu/'], 'name': 'Kentucky State University', 'domains': ['kysu.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['https://www.knoxvillecollege.edu/'], 'name': 'Knoxville College', 'domains': ['knoxvillecollege.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['https://www.lanecollege.edu/'], 'name': 'Lane College', 'domains': ['lanecollege.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://www.lawsonstate.edu/'], 'name': 'Lawson State Community College', 'domains': ['lawsonstate.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['https://www.loc.edu/'], 'name': 'LeMoyne-Owen College', 'domains': ['loc.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['http://livingstone.edu/'], 'name': 'Livingstone College', 'domains': ['livingstone.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['https://home.mmc.edu/'], 'name': 'Meharry Medical College', 'domains': ['mmc.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['https://www.miles.edu/'], 'name': 'Miles College', 'domains': ['miles.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['https://mlaw.edu/'], 'name': 'Miles School of Law', 'domains': ['mlaw.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['https://www.msm.edu/'], 'name': 'Morehouse School of Medicine', 'domains': ['msm.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['https://morrisbrown.edu/'], 'name': 'Morris Brown College', 'domains': ['morrisbrown.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['https://www.morris.edu/'], 'name': 'Morris College', 'domains': ['morris.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['https://www.paine.edu/web/mycampus/home'], 'name': 'Paine College', 'domains': ['paine.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['https://paulquinn.edu/'], 'name': 'Paul Quinn College', 'domains': ['paulquinn.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['https://www.philander.edu/'], 'name': 'Philander Smith College', 'domains': ['philander.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['https://www.rustcollege.edu/'], 'name': 'Rust College', 'domains': ['rustcollege.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['https://www.savannahstate.edu/'], 'name': 'Savannah State University', 'domains': ['savannahstate.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['https://www.selmauniversity.edu/'], 'name': 'Selma University', 'domains': ['selmauniversity.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['https://www.shawu.edu/'], 'name': 'Shaw University', 'domains': ['shawu.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['https://simmonscollegeky.edu/'], 'name': 'Simmons College of Kentucky', 'domains': ['simmonscollegeky.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['https://scsu.edu/'], 'name': 'South Carolina State University', 'domains': ['scsu.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['https://www.suno.edu/'], 'name': 'Southern University at New Orleans', 'domains': ['suno.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['https://www.swcc.edu/'], 'name': 'Southwestern Christian College', 'domains': ['swcc.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['https://www.st-aug.edu/'], 'name': "St. Augustine's University", 'domains': ['st-aug.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['https://stillman.edu/'], 'name': 'Stillman College', 'domains': ['stillman.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['https://www.talladega.edu/'], 'name': 'Talladega College', 'domains': ['talladega.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['https://www.texascollege.edu/'], 'name': 'Texas College', 'domains': ['texascollege.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['https://www.tougaloo.edu/'], 'name': 'Tougaloo College', 'domains': ['tougaloo.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['https://www.vuu.edu/'], 'name': 'Virginia Union University', 'domains': ['vuu.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['https://www.vul.edu/'], 'name': 'Virginia University of Lynchburg', 'domains': ['vul.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['https://www.voorhees.edu/'], 'name': 'Voorhees University', 'domains': ['voorhees.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['https://www.wvstateu.edu/'], 'name': 'West Virginia State University', 'domains': ['wvstate.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['https://www.wileyc.edu/'], 'name': 'Wiley College', 'domains': ['wileyc.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['https://www.wssu.edu/'], 'name': 'Winston-Salem State University', 'domains': ['wssu.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['https://unity.edu/'], 'name': 'Unity Environmental College', 'domains': ['unity.edu'], 'country': 'United States', 'state-province': 'Maine'}
#
# {'alpha_two_code': 'US', 'web_pages': ['https://catawba.edu/'], 'name': 'Catawba College', 'domains': ['catawba.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['https://tamut.edu'], 'name': 'Texas A&M University-Texarkana', 'domains': ['ace.tamut.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['https://belhaven.edu'], 'name': 'Belhaven University', 'domains': ['belhaven.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['https://berry.edu'], 'name': 'Berry College', 'domains': ['berry.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['https://bloomfield.edu'], 'name': 'Bloomfield College', 'domains': ['bloomfield.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['https://bridgew.edu'], 'name': 'Bridgewater State University', 'domains': ['bridgew.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['https://cabrini.edu'], 'name': 'Cabrini University', 'domains': ['cabrini.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['https://caldwell.edu'], 'name': 'Caldwell University', 'domains': ['caldwell.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['https://cornellcollege.edu'], 'name': 'Cornell College', 'domains': ['cornellcollege.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['https://covenant.edu'], 'name': 'Covenant College', 'domains': ['covenant.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['https://csu.edu'], 'name': 'Chicago State University', 'domains': ['csu.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['https://csupueblo.edu'], 'name': 'Colorado State University-Pueblo', 'domains': ['csupueblo.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['https://bau.edu/'], 'name': 'Bay Atlantic University', 'domains': ['bau.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['https://www.siena.edu/'], 'name': 'Siena College', 'domains': ['siena.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['https://txwes.edu/'], 'name': 'Texas Wesleyan University', 'domains': ['txwes.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['https://www.idti.edu/'], 'name': 'Island Drafting & Technical Institute', 'domains': ['idti.edu'], 'country': 'United States', 'state-province': 'NY'}
#
# {'alpha_two_code': 'US', 'web_pages': ['https://www.baypath.edu/'], 'name': 'Bay Path University', 'domains': ['baypath.edu'], 'country': 'United States', 'state-province': 'MA'}
#
# {'alpha_two_code': 'US', 'web_pages': ['https://www.snow.edu/'], 'name': 'Snow College', 'domains': ['snow.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['https://www.scccd.edu/'], 'name': 'State Center Community College District', 'domains': ['scccd.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['https://www.davidsondavie.edu/'], 'name': 'Davidson-Davie Community College', 'domains': ['davidsondavie.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['https://berkeleycollege.edu/'], 'name': 'Berkeley College', 'domains': ['berkeleycollege.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['https://schiller.edu/'], 'name': 'Schiller International University', 'domains': ['schiller.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['https://www.greensboro.edu/'], 'name': 'Greensboro College', 'domains': ['greensboro.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['https://www.vvsaz.org/'], 'name': 'Verde Valley School', 'domains': ['vvsaz.org'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['https://oglethorpe.edu/'], 'name': 'Oglethorpe University', 'domains': ['oglethorpe.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['https://dsdt.edu/'], 'name': 'Detroit School of Technology', 'domains': ['dsdt.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['https://www.northcentralcollege.edu/'], 'name': 'North Central College', 'domains': ['northcentralcollege.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['https://www.umwestern.edu/'], 'name': 'The University of Montana Western', 'domains': ['umwestern.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['https://www.queens.edu/'], 'name': 'Queens University of Charlotte', 'domains': ['queens.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['https://www.lmunet.edu/'], 'name': 'Lincoln Memorial University', 'domains': ['lmunet.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['https://www.greenville.edu/'], 'name': 'Greenville University', 'domains': ['greenville.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['https://suny.oneonta.edu'], 'name': 'State University of New York at Oneonta', 'domains': ['suny.oneonta.edu'], 'country': 'United States', 'state-province': 'New York'}
#
# {'alpha_two_code': 'US', 'web_pages': ['https://www.nmc.edu'], 'name': 'Northwestern Michigan College', 'domains': ['nmc.edu'], 'country': 'United States', 'state-province': 'Michigan'}
#
# {'alpha_two_code': 'US', 'web_pages': ['https://adrian.edu'], 'name': 'Adiran Collge', 'domains': ['adrian.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['https://cuw.edu'], 'name': 'Concordia University Wisconsin', 'domains': ['cuw.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['https://delval.edu'], 'name': 'Delaware Valley University', 'domains': ['delval.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['https://dewv.edu'], 'name': 'Davis & Elkins College', 'domains': ['dewv.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['https://eckerd.edu'], 'name': 'Eckerd College', 'domains': ['eckerd.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['https://uscupstate.edu'], 'name': 'University of South Carolina Upstate', 'domains': ['email.uscupstate.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['https://fairfield.edu'], 'name': 'Fairfield University', 'domains': ['fairfield.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['https://fhda.edu'], 'name': 'Foothill-De Anza Community College District', 'domains': ['fhda.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['https://fmarion.edu'], 'name': 'Francis Marion University', 'domains': ['g.fmarion.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['https://georgefox.edu'], 'name': 'George Fox University', 'domains': ['georgefox.edu'], 'country': 'United States', 'state-province': None}
#
# {'alpha_two_code': 'US', 'web_pages': ['https://grandview.edu'], 'name': 'Grand View University', 'domains': ['grandview.edu'], 'country': 'United States', 'state-province': None}

# %% [markdown]
# ### A complete code for make API call

# %%
import json

class MakeApiCall:

    def get_data(self, api):
        response = requests.get(f"{api}")
        if response.status_code == 200:
            print("sucessfully fetched the data")
            self.formatted_print(response.json())
        else:
            print(
                f"Hello {parameters['username']}, there's a {response.status_code} error with your request")

    def get_user_data(self, api, parameters):
        response = requests.get(f"{api}", params=parameters)
        if response.status_code == 200:
            print("sucessfully fetched the data with parameters provided")
            self.formatted_print(response.json())
        else:
            print(
                f"Hello {parameters['username']}, there's a {response.status_code} error with your request")

    def formatted_print(self, obj):
        text = json.dumps(obj, sort_keys=True, indent=4)
        print(text)

    def __init__(self, api):
        # self.get_data(api)

        parameters = {
            "username": "Sally"
        }
        self.get_user_data(api, parameters)

url_test = "https://numbersapi.p.rapidapi.com/6/21/date"
if __name__ == "__main__":
    api_call = MakeApiCall(url_test)
# Out:
# Hello Sally, there's a 401 error with your request

# %% [markdown]
# ## Read the json data in dataframe

# %%
import pandas as pd

df = pd.json_normalize(response_json)
df
# Out:
#      alpha_two_code                     web_pages  \
# 0                US     [http://www.marywood.edu]
# 1                US  [http://www.lindenwood.edu/]
# 2                US       [https://sullivan.edu/]
# 3                US       [https://www.fscj.edu/]
# 4                US     [https://www.xavier.edu/]
# ...             ...                           ...
# 2293             US       [https://fairfield.edu]
# 2294             US            [https://fhda.edu]
# 2295             US         [https://fmarion.edu]
# 2296             US       [https://georgefox.edu]
# 2297             US       [https://grandview.edu]
#
#                                              name           domains  \
# 0                             Marywood University    [marywood.edu]
# 1                           Lindenwood University  [lindenwood.edu]
# 2                             Sullivan University    [sullivan.edu]
# 3           Florida State College at Jacksonville        [fscj.edu]
# 4                               Xavier University      [xavier.edu]
# ...                                           ...               ...
# 2293                         Fairfield University   [fairfield.edu]
# 2294  Foothill-De Anza Community College District        [fhda.edu]
# 2295                    Francis Marion University   [g.fmarion.edu]
# 2296                        George Fox University   [georgefox.edu]
# 2297                        Grand View University   [grandview.edu]
#
#             country state-province
# 0     United States           None
# 1     United States           None
# 2     United States           None
# 3     United States           None
# 4     United States           None
# ...             ...            ...
# 2293  United States           None
# 2294  United States           None
# 2295  United States           None
# 2296  United States           None
# 2297  United States           None
#
# [2298 rows x 6 columns]

# %% [markdown]
# ## Working with a more complex nested json data

# %%
json_url = "https://itunes.apple.com/gb/rss/customerreviews/id=1500780518/sortBy=mostRecent/json"
r = requests.get(json_url)

# Conversion from JSON to Python:
# data = r.json()
# OR
data = json.loads(r.text)
print(type(data))
# Out:
# <class 'dict'>

# %%
# `json.dumps()` encodes any python object into json formatted string
# Conversion from Python to JSON:
new_json =  json.dumps(data)

# The output will be of a JSON string type.
print(type(new_json))
# Out:
# <class 'str'>

# %%
new_json
# Out:
# '{"feed": {"author": {"name": {"label": "iTunes Store"}, "uri": {"label": "http://www.apple.com/uk/itunes/"}}, "entry": [{"author": {"uri": {"label": "https://itunes.apple.com/gb/reviews/id1226434175"}, "name": {"label": "_eddyne"}, "label": ""}, "updated": {"label": "2024-02-13T00:57:44-07:00"}, "im:rating": {"label": "5"}, "im:version": {"label": "3.0.13"}, "id": {"label": "10933503223"}, "title": {"label": "Best meditation app"}, "content": {"label": "This app was recommended to me by hamza and it\\u2019s completely changed my life . Thank you Medito .", "attributes": {"type": "text"}}, "link": {"attributes": {"rel": "related", "href": "https://itunes.apple.com/gb/review?id=1500780518&type=Purple%20Software"}}, "im:voteSum": {"label": "0"}, "im:contentType": {"attributes": {"term": "Application", "label": "Application"}}, "im:voteCount": {"label": "0"}}, {"author": {"uri": {"label": "https://itunes.apple.com/gb/reviews/id1196688209"}, "name": {"label": "KayFaraday69"}, "label": ""}, "updated": {"label": "2024-02-04T13:15:09-07:00"}, "im:rating": {"label": "3"}, "im:version": {"label": "3.0.13"}, "id": {"label": "10902191584"}, "title": {"label": "Good but could be a lot better"}, "content": {"label": "I like the recordings themselves they are cool and the course is cool too but please the app feels so slow sometimes and please do a way to make an account because I lose all my progress and stats in the course when I have to uninstall and reinstall the app, so if you could do a way to back up the progress that would be wonderful", "attributes": {"type": "text"}}, "link": {"attributes": {"rel": "related", "href": "https://itunes.apple.com/gb/review?id=1500780518&type=Purple%20Software"}}, "im:voteSum": {"label": "0"}, "im:contentType": {"attributes": {"term": "Application", "label": "Application"}}, "im:voteCount": {"label": "0"}}, {"author": {"uri": {"label": "https://itunes.apple.com/gb/reviews/id35697210"}, "name": {"label": "Jonathan-R"}, "label": ""}, "updated": {"label": "2024-01-29T14:26:09-07:00"}, "im:rating": {"label": "1"}, "im:version": {"label": "3.0.13"}, "id": {"label": "10878856044"}, "title": {"label": "Seems promising but app doesn\\u2019t work"}, "content": {"label": "Intermittent \\u201ctype\\u201d errors make the app completely unusable unfortunately.", "attributes": {"type": "text"}}, "link": {"attributes": {"rel": "related", "href": "https://itunes.apple.com/gb/review?id=1500780518&type=Purple%20Software"}}, "im:voteSum": {"label": "0"}, "im:contentType": {"attributes": {"term": "Application", "label": "Application"}}, "im:voteCount": {"label": "0"}}, {"author": {"uri": {"label": "https://itunes.apple.com/gb/reviews/id110585716"}, "name": {"label": "bapanada"}, "label": ""}, "updated": {"label": "2024-01-18T16:02:49-07:00"}, "im:rating": {"label": "3"}, "im:version": {"label": "3.0.13"}, "id": {"label": "10837489637"}, "title": {"label": "Great resource, shame about the AI images"}, "content": {"label": "I previously left a 5-star rating because I have found Medito to be an excellent app and resource, and I am so thankful that it is ad-free and doesn\\u2019t harvest my data. I use it every day and am on a nearly 800-day streak at this point. However, with the recent UI update, I am really disappointed that the team decided to change from the previous simple, consistent artwork to a bunch of AI images. They are obviously modelled after a particular artist\\u2019s work in an attempt to look consistent, and I highly doubt that artist was consulted or compensated for this unethical scraping of their work. Additionally, I find many of the images deeply unsettling and disturbing to look at: the opposite of what a meditation app should do! I have found myself more and more reluctant to open up the app because of this, and I\\u2019m really sad about that. I hope the Medito team will consider commissioning some art from a human being soon.", "attributes": {"type": "text"}}, "link": {"attributes": {"rel": "related ...

# %%
print(json.dumps(data, sort_keys=True, indent=5))
# Out:
# {
#      "feed": {
#           "author": {
#                "name": {
#                     "label": "iTunes Store"
#                },
#                "uri": {
#                     "label": "http://www.apple.com/uk/itunes/"
#                }
#           },
#           "entry": [
#                {
#                     "author": {
#                          "label": "",
#                          "name": {
#                               "label": "_eddyne"
#                          },
#                          "uri": {
#                               "label": "https://itunes.apple.com/gb/reviews/id1226434175"
#                          }
#                     },
#                     "content": {
#                          "attributes": {
#                               "type": "text"
#                          },
#                          "label": "This app was recommended to me by hamza and it\u2019s completely changed my life . Thank you Medito ."
#                     },
#                     "id": {
#                          "label": "10933503223"
#                     },
#                     "im:contentType": {
#                          "attributes": {
#                               "label": "Application",
#                               "term": "Application"
#                          }
#                     },
#                     "im:rating": {
#                          "label": "5"
#                     },
#                     "im:version": {
#                          "label": "3.0.13"
#                     },
#                     "im:voteCount": {
#                          "label": "0"
#                     },
#                     "im:voteSum": {
#                          "label": "0"
#                     },
#                     "link": {
#                          "attributes": {
#                               "href": "https://itunes.apple.com/gb/review?id=1500780518&type=Purple%20Software",
#                               "rel": "related"
#                          }
#                     },
#                     "title": {
#                          "label": "Best meditation app"
#                     },
#                     "updated": {
#                          "label": "2024-02-13T00:57:44-07:00"
#                     }
#                },
#                {
#                     "author": {
#                          "label": "",
#                          "name": {
#                               "label": "KayFaraday69"
#                          },
#                          "uri": {
#                               "label": "https://itunes.apple.com/gb/reviews/id1196688209"
#                          }
#                     },
#                     "content": {
#                          "attributes": {
#                               "type": "text"
#                          },
#                          "label": "I like the recordings themselves they are cool and the course is cool too but please the app feels so slow sometimes and please do a way to make an account because I lose all my progress and stats in the course when I have to uninstall and reinstall the app, so if you could do a way to back up the progress that would be wonderful"
#                     },
#                     "id": {
#                          "label": "10902191584"
#                     },
#                     "im:contentType": {
#                          "attributes": {
#                               "label": "Application",
#                               "term": "Application"
#                          }
#                     },
#                     "im:rating": {
#                          "label": "3"
#                     },
#                     "im:version": {
#                          "label": "3.0.13"
#                     },
#                     "im:voteCount": {
#                          "label": "0"
#                     },
#                     "im:voteSum": {
#                          "label": "0"
#                     },
#                     "link": {
#                          "attributes": {
#                               "href": "https://itunes.apple.com/gb/review?id=1500780518&type=Purple%20Software",
#                               "rel": "related"
#                          }
#                     },
#                     "title": {
#                          "label": "Good but could be a lot better"
#                     },
#                     "updated": {
#                          "label": "2024-02-04T13:15:09-07:00"
#                     }
#                },
#                {
#                     "author": {
#                          "label": "",
#                          "name": {
#                               "label": "Jonathan-R"
#                          },
#                          "uri": {
#                               "label": "https://itunes.apple.com/gb/reviews/id35697210"
#                          }
#                     },
#                     "content": {
#                          "attributes": {
#                               "type": "text"
#                          },
#                          "label": "Intermittent \u201ctype\u201d errors make the app completely unusable unfortunately."
#                     },
#                     "id": {
#                          "label": "10878856044"
#                     },
#                     "im:contentType": {
#                          "attributes": {
#                               "label": "Application",
#                               "term": "Application"
#                          }
#                     },
#                     "im:rating": {
#                          "label": "1"
#                     },
#                     "im:version": {
#                          "label": "3.0.13"
#                     },
#                     "im:voteCount": {
#                          "label": "0"
#                     },
#                     "im:voteSum": {
#                          "label": "0"
#                     },
#                     "link": {
#                          "attributes": {
#                               "href": "https://itunes.apple.com/gb/review?id=1500780518&type=Purple%20Software",
#                               "rel": "related"
#                          }
#                     },
#                     "title": {
#                          "label": "Seems promising but app doesn\u2019t work"
#                     },
#                     "updated": {
#                          "label": "2024-01-29T14:26:09-07:00"
#                     }
#                },
#                {
#                     "author": {
#                          "label": "",
#                          "name": {
#                               "label": "bapanada"
#                          },
#                          "uri": {
#                               "label": "https://itunes.apple.com/gb/reviews/id110585716"
#                          }
#                     },
#                     "content": {
#                          "attributes": {
#                               "type": "text"
#                          },
#                          "label": "I previously left a 5-star rating because I have found Medito to be an excellent app and resource, and I am so thankful that it is ad-free and doesn\u2019t harvest my data. I use it every day and am on a nearly 800-day streak at this point. However, with the recent UI update, I am really disappointed that the team decided to change from the previous simple, consistent artwork to a bunch of AI images. They are obviously modelled after a particular artist\u2019s work in an attempt to look consistent, and I highly doubt that artist was consulted or compensated for this unethical scraping of their work. Additionally, I find many of the images deeply unsettling and disturbing to look at: the opposite of what a meditation app should do! I have found myself more and more reluctant to open up the app because of this, and I\u2019m really sad about that. I hope the Medito team will consider commissioning some art from a human being soon."
#                     },
#                     "id": {
#                          "label": "10837489637"
#                     },
#                     "im:contentType": {
#                          "attributes": {
#                               "label": "Application",
#                               "term": "Application"
#                          }
#                     },
#                     "im:rating": {
#                          "label": "3"
#                     },
#                     "im:version": {
#                          "label": "3.0.13"
#                     },
#                     "im:voteCount": {
#                          "label": "0"
#                     },
#                     "im:voteSum": {
#                          "label": "0"
#                     },
#                     "link": {
#                          "attributes": {
#                               "href": "https://itunes.apple.com/gb/review?id=1500780518&type=Purple%20Software",
#                               "rel": "related"
#                          }
#                     },
#                     "title": {
#                          "label": "Great resource, shame about the AI images"
#                     },
#                     "updated": {
#                          "label": "2024-01-18T16:02:49-07:00"
#                     }
#                },
#                {
#                     "author": {
#                          "label": "",
#                          "name": {
#                               "label": "Adithebaddie."
#                          },
#                          "uri": {
#                               "label": "https://itunes.apple.com/gb/reviews/id967020663"
#                          }
#                     },
#                     "content": {
#                          "attributes": {
#                               "type": "text"
#                          },
#                          "label": "Follow the Medito course, and you\u2019ll find peace, happiness, and an overall positive change in your life. Then do the daily meditations/work through a different pack. \n\nHonestly life changing"
#                     },
#                     "id": {
#                          "label": "10754771030"
#                     },
#                     "im:contentType": {
#                          "attributes": {
#                               "label": "Application",
#                               "term": "Application"
#                          }
#                     },
#                     "im:rating": {
#                          "label": "5"
#                     },
#                     "im:version": {
#                          "label": "3.0.13"
#                     },
#                     "im:voteCount": {
#                          "label": "0"
#                     },
#                     "im:voteSum": {
#                          "label": "0"
#                     },
#                     "link": {
#                          "attributes": {
#                               "href": "https://itunes.apple.com/gb/review?id=1500780518&type=Purple%20Software",
#                               "rel": "related"
#                          }
#                     },
#                     "title": {
#                          "label": "Amazing amazing amazing"
#                     },
#                     "updated": {
#                          "label": "2023-12-28T05:44:34-07:00"
#                     }
#                },
#                {
#                     "author": {
#                          "label": "",
#                          "name": {
#                               "label": "Joel\ud83c\udf3b"
#                          },
#                          "uri": {
#                               "label": "https://itunes.apple.com/gb/reviews/id824093642"
#                          }
#                     },
#                     "content": {
#                          "attributes": {
#                               "type": "text"
#                          },
#                          "label": "Happy to give my 3rd review as I\u2019ve downloaded the app in my new device and I can add a brand new one\ud83c\udf1fI couldn\u2019t stay without this app. It\u2019s really a great journey companion that recently has had some troubles due to some expenses they had in keeping the app free (from ads as well). At first I didn\u2019t like the new interface actually, I always loved this app for its simplicity and since its renewal it looks a bit more sophisticated, but I have adapted to it now and I am happy as usual\ud83d\ude0a after all isn\u2019t change the only constant? And thanks to apps like Medito is easy to accept every life change with a conscious attitude. \nHappy meditation to everyone!\ud83c\udf38"
#                     },
#                     "id": {
#                          "label": "10754725996"
#                     },
#                     "im:contentType": {
#                          "attributes": {
#                               "label": "Application",
#                               "term": "Application"
#                          }
#                     },
#                     "im:rating": {
#                          "label": "5"
#                     },
#                     "im:version": {
#                          "label": "3.0.13"
#                     },
#                     "im:voteCount": {
#                          "label": "0"
#                     },
#                     "im:voteSum": {
#                          "label": "0"
#                     },
#                     "link": {
#                          "attributes": {
#                               "href": "https://itunes.apple.com/gb/review?id=1500780518&type=Purple%20Software",
#                               "rel": "related"
#                          }
#                     },
#                     "title": {
#                          "label": "This is my 3rd review about this app"
#                     },
#                     "updated": {
#                          "label": "2023-12-28T05:31:13-07:00"
#                     }
#                },
#                {
#                     "author": {
#                          "label": "",
#                          "name": {
#                               "label": "Adam Elharrati"
#                          },
#                          "uri": {
#                               "label": "https://itunes.apple.com/gb/reviews/id1226425216"
#                          }
#                     },
#                     "content": {
#                          "attributes": {
#                               "type": "text"
#                          },
#                          "label": "App really helped me get into the habit of meditating, and some of their packs such as the new personal insights one are quite profound. The way that the courses are structured with a focus on improving and delving deeper really helps moving on from using meditation as a simple breathing exercise into something more."
#                     },
#                     "id": {
#                          "label": "10751855027"
#                     },
#                     "im:contentType": {
#                          "attributes": {
#                               "label": "Application",
#                               "term": "Application"
#                          }
#                     },
#                     "im:rating": {
#                          "label": "5"
#                     },
#                     "im:version": {
#                          "label": "3.0.13"
#                     },
#                     "im:voteCount": {
#                          "label": "0"
#                     },
#                     "im:voteSum": {
#                          "label": "0"
#                     },
#                     "link": {
#                          "attributes": {
#                               "href": "https://itunes.apple.com/gb/review?id=1500780518&type=Purple%20Software",
#                               "rel": "related"
#                          }
#                     },
#                     "title": {
#                          "label": "Amazing App, amazing packs"
#                     },
#                     "updated": {
#                          "label": "2023-12-27T10:59:41-07:00"
#                     }
#                },
#                {
#                     "author": {
#                          "label": "",
#                          "name": {
#                               "label": "Adrian0001928"
#                          },
#                          "uri": {
#                               "label": "https://itunes.apple.com/gb/reviews/id580563869"
#                          }
#                     },
#                     "content": {
#                          "attributes": {
#                               "type": "text"
#                          },
#                          "label": "Has everything to get you started with meditation. Super easy to follow and very effective. Definitely recommend"
#                     },
#                     "id": {
#                          "label": "10643712004"
#                     },
#                     "im:contentType": {
#                          "attributes": {
#                               "label": "Application",
#                               "term": "Application"
#                          }
#                     },
#                     "im:rating": {
#                          "label": "5"
#                     },
#                     "im:version": {
#                          "label": "3.0.12"
#                     },
#                     "im:voteCount": {
#                          "label": "0"
#                     },
#                     "im:voteSum": {
#                          "label": "0"
#                     },
#                     "link": {
#                          "attributes": {
#                               "href": "https://itunes.apple.com/gb/review?id=1500780518&type=Purple%20Software",
#                               "rel": "related"
#                          }
#                     },
#                     "title": {
#                          "label": "Amazing"
#                     },
#                     "updated": {
#                          "label": "2023-11-30T17:19:36-07:00"
#                     }
#                },
#                {
#                     "author": {
#                          "label": "",
#                          "name": {
#                               "label": "Baggs00"
#                          },
#                          "uri": {
#                               "label": "https://itunes.apple.com/gb/reviews/id750327845"
#                          }
#                     },
#                     "content": {
#                          "attributes": {
#                               "type": "text"
#                          },
#                          "label": "I\u2019ve tried all the meditation apps, calm, headspace, balance etc, and none of them compare to this one. It feels like what a meditation app should be. The course guides you gently through all the fundamentals while actually progressing you ( in others found the courses to be tedious and drain your interest, making meditation feel like a chore rather than a want) I have progressed to longer meditations quicker than with any of the other apps. Best of all it\u2019s free, I think this is the reason it\u2019s the best because it\u2019s made by people who have a passion to deliver this to everyone without a monetary motivation behind it. They could be making a lot of money but chose not to and that care you can feel in the content they provide. Well designed as well. 10/10 for this app, could not praise any more, I recommend it to everyone."
#                     },
#                     "id": {
#                          "label": "10629099850"
#                     },
#                     "im:contentType": {
#                          "attributes": {
#                               "label": "Application",
#                               "term": "Application"
#                          }
#                     },
#                     "im:rating": {
#                          "label": "5"
#                     },
#                     "im:version": {
#                          "label": "3.0.11"
#                     },
#                     "im:voteCount": {
#                          "label": "0"
#                     },
#                     "im:voteSum": {
#                          "label": "0"
#                     },
#                     "link": {
#                          "attributes": {
#                               "href": "https://itunes.apple.com/gb/review?id=1500780518&type=Purple%20Software",
#                               "rel": "related"
#                          }
#                     },
#                     "title": {
#                          "label": "Best meditation app and it\u2019s free!!!"
#                     },
#                     "updated": {
#                          "label": "2023-11-26T14:43:30-07:00"
#                     }
#                },
#                {
#                     "author": {
#                          "label": "",
#                          "name": {
#                               "label": "C.Breezy19"
#                          },
#                          "uri": {
#                               "label": "https://itunes.apple.com/gb/reviews/id537801546"
#                          }
#                     },
#                     "content": {
#                          "attributes": {
#                               "type": "text"
#                          },
#                          "label": "I think that Medito is a God send! I love this app I use it almost everyday, and what is great is that if you\u2019re a beginner to meditation, they\u2019ve got your back covered with all the courses including an introduction to meditation and mindfulness which is super helpful and what\u2019s best is that it\u2019s FREE! I love how well planned out the app is and with the recent update I believe there\u2019s a lot more content for you to explore and dig into. I\u2019d definitely recommend this app if you are interested in starting meditation."
#                     },
#                     "id": {
#                          "label": "10612028965"
#                     },
#                     "im:contentType": {
#                          "attributes": {
#                               "label": "Application",
#                               "term": "Application"
#                          }
#                     },
#                     "im:rating": {
#                          "label": "5"
#                     },
#                     "im:version": {
#                          "label": "3.0.11"
#                     },
#                     "im:voteCount": {
#                          "label": "0"
#                     },
#                     "im:voteSum": {
#                          "label": "0"
#                     },
#                     "link": {
#                          "attributes": {
#                               "href": "https://itunes.apple.com/gb/review?id=1500780518&type=Purple%20Software",
#                               "rel": "related"
#                          }
#                     },
#                     "title": {
#                          "label": "Definitely recommend"
#                     },
#                     "updated": {
#                          "label": "2023-11-22T02:33:43-07:00"
#                     }
#                },
#                {
#                     "author": {
#                          "label": "",
#                          "name": {
#                               "label": "Mxpze"
#                          },
#                          "uri": {
#                               "label": "https://itunes.apple.com/gb/reviews/id641668833"
#                          }
#                     },
#                     "content": {
#                          "attributes": {
#                               "type": "text"
#                          },
#                          "label": "If you\u2019re someone who wants to meditate for free without any ads in peace, this app is for you. This app has a lot of cool features to encourage you to actively meditate everyday. I am ever so grateful for the creators of this app. I have made all my friends download and use this app, the feedback from them has been great!\n\nThank you Steven, Will and the medito team!"
#                     },
#                     "id": {
#                          "label": "10606729755"
#                     },
#                     "im:contentType": {
#                          "attributes": {
#                               "label": "Application",
#                               "term": "Application"
#                          }
#                     },
#                     "im:rating": {
#                          "label": "5"
#                     },
#                     "im:version": {
#                          "label": "3.0.11"
#                     },
#                     "im:voteCount": {
#                          "label": "0"
#                     },
#                     "im:voteSum": {
#                          "label": "0"
#                     },
#                     "link": {
#                          "attributes": {
#                               "href": "https://itunes.apple.com/gb/review?id=1500780518&type=Purple%20Software",
#                               "rel": "related"
#                          }
#                     },
#                     "title": {
#                          "label": "Best app for meditation"
#                     },
#                     "updated": {
#                          "label": "2023-11-20T13:04:42-07:00"
#                     }
#                },
#                {
#                     "author": {
#                          "label": "",
#                          "name": {
#                               "label": "TonyDaBoss123"
#                          },
#                          "uri": {
#                               "label": "https://itunes.apple.com/gb/reviews/id1054235828"
#                          }
#                     },
#                     "content": {
#                          "attributes": {
#                               "type": "text"
#                          },
#                          "label": "Very good. Good quality meditation. I would recommend!"
#                     },
#                     "id": {
#                          "label": "10603508884"
#                     },
#                     "im:contentType": {
#                          "attributes": {
#                               "label": "Application",
#                               "term": "Application"
#                          }
#                     },
#                     "im:rating": {
#                          "label": "5"
#                     },
#                     "im:version": {
#                          "label": "3.0.11"
#                     },
#                     "im:voteCount": {
#                          "label": "0"
#                     },
#                     "im:voteSum": {
#                          "label": "0"
#                     },
#                     "link": {
#                          "attributes": {
#                               "href": "https://itunes.apple.com/gb/review?id=1500780518&type=Purple%20Software",
#                               "rel": "related"
#                          }
#                     },
#                     "title": {
#                          "label": "Best meditation app out there"
#                     },
#                     "updated": {
#                          "label": "2023-11-19T14:40:18-07:00"
#                     }
#                },
#                {
#                     "author": {
#                          "label": "",
#                          "name": {
#                               "label": "MihaiTeo"
#                          },
#                          "uri": {
#                               "label": "https://itunes.apple.com/gb/reviews/id1297206556"
#                          }
#                     },
#                     "content": {
#                          "attributes": {
#                               "type": "text"
#                          },
#                          "label": "Best app for meditation"
#                     },
#                     "id": {
#                          "label": "10603365979"
#                     },
#                     "im:contentType": {
#                          "attributes": {
#                               "label": "Application",
#                               "term": "Application"
#                          }
#                     },
#                     "im:rating": {
#                          "label": "5"
#                     },
#                     "im:version": {
#                          "label": "3.0.11"
#                     },
#                     "im:voteCount": {
#                          "label": "0"
#                     },
#                     "im:voteSum": {
#                          "label": "0"
#                     },
#                     "link": {
#                          "attributes": {
#                               "href": "https://itunes.apple.com/gb/review?id=1500780518&type=Purple%20Software",
#                               "rel": "related"
#                          }
#                     },
#                     "title": {
#                          "label": "Best app for meditation"
#                     },
#                     "updated": {
#                          "label": "2023-11-19T13:36:30-07:00"
#                     }
#                },
#                {
#                     "author": {
#                          "label": "",
#                          "name": {
#                               "label": "nshshshhshahhs"
#                          },
#                          "uri": {
#                               "label": "https://itunes.apple.com/gb/reviews/id758237746"
#                          }
#                     },
#                     "content": {
#                          "attributes": {
#                               "type": "text"
#                          },
#                          "label": "Download to become Adonis"
#                     },
#                     "id": {
#                          "label": "10602436694"
#                     },
#                     "im:contentType": {
#                          "attributes": {
#                               "label": "Application",
#                               "term": "Application"
#                          }
#                     },
#                     "im:rating": {
#                          "label": "5"
#                     },
#                     "im:version": {
#                          "label": "3.0.11"
#                     },
#                     "im:voteCount": {
#                          "label": "0"
#                     },
#                     "im:voteSum": {
#                          "label": "0"
#                     },
#                     "link": {
#                          "attributes": {
#                               "href": "https://itunes.apple.com/gb/review?id=1500780518&type=Purple%20Software",
#                               "rel": "related"
#                          }
#                     },
#                     "title": {
#                          "label": "Hamza"
#                     },
#                     "updated": {
#                          "label": "2023-11-19T07:51:26-07:00"
#                     }
#                },
#                {
#                     "author": {
#                          "label": "",
#                          "name": {
#                               "label": "93@/)3@/\u00a3:7;\u00a338,:)/&/,.,.?"
#                          },
#                          "uri": {
#                               "label": "https://itunes.apple.com/gb/reviews/id1242075443"
#                          }
#                     },
#                     "content": {
#                          "attributes": {
#                               "type": "text"
#                          },
#                          "label": "An app ran purely off optional donations that provides a free meditation service for everyone. Medito foundation are truly amazing and selfless people. Always 5 stars from me \ud83d\ude0a"
#                     },
#                     "id": {
#                          "label": "10597502088"
#                     },
#                     "im:contentType": {
#                          "attributes": {
#                               "label": "Application",
#                               "term": "Application"
#                          }
#                     },
#                     "im:rating": {
#                          "label": "5"
#                     },
#                     "im:version": {
#                          "label": "3.0.11"
#                     },
#                     "im:voteCount": {
#                          "label": "0"
#                     },
#                     "im:voteSum": {
#                          "label": "0"
#                     },
#                     "link": {
#                          "attributes": {
#                               "href": "https://itunes.apple.com/gb/review?id=1500780518&type=Purple%20Software",
#                               "rel": "related"
#                          }
#                     },
#                     "title": {
#                          "label": "An amazing app - and completely free too."
#                     },
#                     "updated": {
#                          "label": "2023-11-17T23:40:33-07:00"
#                     }
#                },
#                {
#                     "author": {
#                          "label": "",
#                          "name": {
#                               "label": "steven009282"
#                          },
#                          "uri": {
#                               "label": "https://itunes.apple.com/gb/reviews/id1475476224"
#                          }
#                     },
#                     "content": {
#                          "attributes": {
#                               "type": "text"
#                          },
#                          "label": "Couldn\u2019t recommend this enough"
#                     },
#                     "id": {
#                          "label": "10597494427"
#                     },
#                     "im:contentType": {
#                          "attributes": {
#                               "label": "Application",
#                               "term": "Application"
#                          }
#                     },
#                     "im:rating": {
#                          "label": "5"
#                     },
#                     "im:version": {
#                          "label": "3.0.11"
#                     },
#                     "im:voteCount": {
#                          "label": "0"
#                     },
#                     "im:voteSum": {
#                          "label": "0"
#                     },
#                     "link": {
#                          "attributes": {
#                               "href": "https://itunes.apple.com/gb/review?id=1500780518&type=Purple%20Software",
#                               "rel": "related"
#                          }
#                     },
#                     "title": {
#                          "label": "Best meditation app ever!"
#                     },
#                     "updated": {
#                          "label": "2023-11-17T23:36:58-07:00"
#                     }
#                },
#                {
#                     "author": {
#                          "label": "",
#                          "name": {
#                               "label": "Katya_%"
#                          },
#                          "uri": {
#                               "label": "https://itunes.apple.com/gb/reviews/id601846694"
#                          }
#                     },
#                     "content": {
#                          "attributes": {
#                               "type": "text"
#                          },
#                          "label": "Great app! Highly recommend! \u2b50\ufe0f\u2b50\ufe0f\u2b50\ufe0f\u2b50\ufe0f\u2b50\ufe0f"
#                     },
#                     "id": {
#                          "label": "10593839072"
#                     },
#                     "im:contentType": {
#                          "attributes": {
#                               "label": "Application",
#                               "term": "Application"
#                          }
#                     },
#                     "im:rating": {
#                          "label": "5"
#                     },
#                     "im:version": {
#                          "label": "3.0.10"
#                     },
#                     "im:voteCount": {
#                          "label": "0"
#                     },
#                     "im:voteSum": {
#                          "label": "0"
#                     },
#                     "link": {
#                          "attributes": {
#                               "href": "https://itunes.apple.com/gb/review?id=1500780518&type=Purple%20Software",
#                               "rel": "related"
#                          }
#                     },
#                     "title": {
#                          "label": "Great app!"
#                     },
#                     "updated": {
#                          "label": "2023-11-16T22:10:59-07:00"
#                     }
#                },
#                {
#                     "author": {
#                          "label": "",
#                          "name": {
#                               "label": "heloo mate"
#                          },
#                          "uri": {
#                               "label": "https://itunes.apple.com/gb/reviews/id577881795"
#                          }
#                     },
#                     "content": {
#                          "attributes": {
#                               "type": "text"
#                          },
#                          "label": "I have been using Medito for a few months now starting as a beginner and I can say that meditation has benefited my life in such a positive way.\n\nMedito is free and easy to use just starting off small going through the different meditation packs. \n\nI don\u2019t rate many apps but I would and do recommend this app to so many people.\n\nDefiantly deserving of 5 stars."
#                     },
#                     "id": {
#                          "label": "10589533624"
#                     },
#                     "im:contentType": {
#                          "attributes": {
#                               "label": "Application",
#                               "term": "Application"
#                          }
#                     },
#                     "im:rating": {
#                          "label": "5"
#                     },
#                     "im:version": {
#                          "label": "3.0.10"
#                     },
#                     "im:voteCount": {
#                          "label": "0"
#                     },
#                     "im:voteSum": {
#                          "label": "0"
#                     },
#                     "link": {
#                          "attributes": {
#                               "href": "https://itunes.apple.com/gb/review?id=1500780518&type=Purple%20Software",
#                               "rel": "related"
#                          }
#                     },
#                     "title": {
#                          "label": "I would highly recommend for any level of meditation."
#                     },
#                     "updated": {
#                          "label": "2023-11-15T14:54:21-07:00"
#                     }
#                },
#                {
#                     "author": {
#                          "label": "",
#                          "name": {
#                               "label": "kslhawkem"
#                          },
#                          "uri": {
#                               "label": "https://itunes.apple.com/gb/reviews/id1309296731"
#                          }
#                     },
#                     "content": {
#                          "attributes": {
#                               "type": "text"
#                          },
#                          "label": "Amazing App. On a 70 Day Streak Currently. Thankful \ud83d\ude4f"
#                     },
#                     "id": {
#                          "label": "10589426570"
#                     },
#                     "im:contentType": {
#                          "attributes": {
#                               "label": "Application",
#                               "term": "Application"
#                          }
#                     },
#                     "im:rating": {
#                          "label": "5"
#                     },
#                     "im:version": {
#                          "label": "3.0.10"
#                     },
#                     "im:voteCount": {
#                          "label": "0"
#                     },
#                     "im:voteSum": {
#                          "label": "0"
#                     },
#                     "link": {
#                          "attributes": {
#                               "href": "https://itunes.apple.com/gb/review?id=1500780518&type=Purple%20Software",
#                               "rel": "related"
#                          }
#                     },
#                     "title": {
#                          "label": "Amazing"
#                     },
#                     "updated": {
#                          "label": "2023-11-15T14:04:58-07:00"
#                     }
#                },
#                {
#                     "author": {
#                          "label": "",
#                          "name": {
#                               "label": "txmmzy"
#                          },
#                          "uri": {
#                               "label": "https://itunes.apple.com/gb/reviews/id1444600231"
#                          }
#                     },
#                     "content": {
#                          "attributes": {
#                               "type": "text"
#                          },
#                          "label": "The app is free! And there\u2019s no ads, try it \u270c\ufe0f"
#                     },
#                     "id": {
#                          "label": "10588141628"
#                     },
#                     "im:contentType": {
#                          "attributes": {
#                               "label": "Application",
#                               "term": "Application"
#                          }
#                     },
#                     "im:rating": {
#                          "label": "5"
#                     },
#                     "im:version": {
#                          "label": "3.0.10"
#                     },
#                     "im:voteCount": {
#                          "label": "0"
#                     },
#                     "im:voteSum": {
#                          "label": "0"
#                     },
#                     "link": {
#                          "attributes": {
#                               "href": "https://itunes.apple.com/gb/review?id=1500780518&type=Purple%20Software",
#                               "rel": "related"
#                          }
#                     },
#                     "title": {
#                          "label": "What are you waiting for?"
#                     },
#                     "updated": {
#                          "label": "2023-11-15T05:48:44-07:00"
#                     }
#                },
#                {
#                     "author": {
#                          "label": "",
#                          "name": {
#                               "label": "TSAgscasfz"
#                          },
#                          "uri": {
#                               "label": "https://itunes.apple.com/gb/reviews/id1282646886"
#                          }
#                     },
#                     "content": {
#                          "attributes": {
#                               "type": "text"
#                          },
#                          "label": "An incredible app that has greatly helped me and changed my life for the better I would highly recommend and thanks a lot Medito"
#                     },
#                     "id": {
#                          "label": "10585999423"
#                     },
#                     "im:contentType": {
#                          "attributes": {
#                               "label": "Application",
#                               "term": "Application"
#                          }
#                     },
#                     "im:rating": {
#                          "label": "5"
#                     },
#                     "im:version": {
#                          "label": "3.0.10"
#                     },
#                     "im:voteCount": {
#                          "label": "0"
#                     },
#                     "im:voteSum": {
#                          "label": "0"
#                     },
#                     "link": {
#                          "attributes": {
#                               "href": "https://itunes.apple.com/gb/review?id=1500780518&type=Purple%20Software",
#                               "rel": "related"
#                          }
#                     },
#                     "title": {
#                          "label": "Best meditation app"
#                     },
#                     "updated": {
#                          "label": "2023-11-14T13:57:20-07:00"
#                     }
#                },
#                {
#                     "author": {
#                          "label": "",
#                          "name": {
#                               "label": "AshishJoshi1965"
#                          },
#                          "uri": {
#                               "label": "https://itunes.apple.com/gb/reviews/id178350449"
#                          }
#                     },
#                     "content": {
#                          "attributes": {
#                               "type": "text"
#                          },
#                          "label": "An app-sized mediation guru in your pocket to help you to navigate and understand what can appear to be a daunting and confusing journey. It\u2019s  a joy to use! Highly recommended!"
#                     },
#                     "id": {
#                          "label": "10585474388"
#                     },
#                     "im:contentType": {
#                          "attributes": {
#                               "label": "Application",
#                               "term": "Application"
#                          }
#                     },
#                     "im:rating": {
#                          "label": "5"
#                     },
#                     "im:version": {
#                          "label": "3.0.10"
#                     },
#                     "im:voteCount": {
#                          "label": "0"
#                     },
#                     "im:voteSum": {
#                          "label": "0"
#                     },
#                     "link": {
#                          "attributes": {
#                               "href": "https://itunes.apple.com/gb/review?id=1500780518&type=Purple%20Software",
#                               "rel": "related"
#                          }
#                     },
#                     "title": {
#                          "label": "Absolutely Wonderful!"
#                     },
#                     "updated": {
#                          "label": "2023-11-14T10:11:56-07:00"
#                     }
#                },
#                {
#                     "author": {
#                          "label": "",
#                          "name": {
#                               "label": "UnicornFlosser_451"
#                          },
#                          "uri": {
#                               "label": "https://itunes.apple.com/gb/reviews/id634027578"
#                          }
#                     },
#                     "content": {
#                          "attributes": {
#                               "type": "text"
#                          },
#                          "label": "I have been using Medito for some time now and it has really helped me to start meditating. It\u2019s very quick and easy to use, so even if you just have 3 minutes you can do a session. I really like the simplicity of the interface and I have overall really benefitted from using the app."
#                     },
#                     "id": {
#                          "label": "10583827963"
#                     },
#                     "im:contentType": {
#                          "attributes": {
#                               "label": "Application",
#                               "term": "Application"
#                          }
#                     },
#                     "im:rating": {
#                          "label": "5"
#                     },
# ...
#                     },
#                     "id": {
#                          "label": "10035254012"
#                     },
#                     "im:contentType": {
#                          "attributes": {
#                               "label": "Application",
#                               "term": "Application"
#                          }
#                     },
#                     "im:rating": {
#                          "label": "5"
#                     },
#                     "im:version": {
#                          "label": "2.0.47"
#                     },
#                     "im:voteCount": {
#                          "label": "0"
#                     },
#                     "im:voteSum": {
#                          "label": "0"
#                     },
#                     "link": {
#                          "attributes": {
#                               "href": "https://itunes.apple.com/gb/review?id=1500780518&type=Purple%20Software",
#                               "rel": "related"
#                          }
#                     },
#                     "title": {
#                          "label": "Life changing"
#                     },
#                     "updated": {
#                          "label": "2023-06-14T23:04:30-07:00"
#                     }
#                },
#                {
#                     "author": {
#                          "label": "",
#                          "name": {
#                               "label": "Oligog"
#                          },
#                          "uri": {
#                               "label": "https://itunes.apple.com/gb/reviews/id380922049"
#                          }
#                     },
#                     "content": {
#                          "attributes": {
#                               "type": "text"
#                          },
#                          "label": "Changed my life. Thank you Medito"
#                     },
#                     "id": {
#                          "label": "9915148160"
#                     },
#                     "im:contentType": {
#                          "attributes": {
#                               "label": "Application",
#                               "term": "Application"
#                          }
#                     },
#                     "im:rating": {
#                          "label": "5"
#                     },
#                     "im:version": {
#                          "label": "2.0.47"
#                     },
#                     "im:voteCount": {
#                          "label": "0"
#                     },
#                     "im:voteSum": {
#                          "label": "0"
#                     },
#                     "link": {
#                          "attributes": {
#                               "href": "https://itunes.apple.com/gb/review?id=1500780518&type=Purple%20Software",
#                               "rel": "related"
#                          }
#                     },
#                     "title": {
#                          "label": "\ud83d\udc4f\ud83d\udc4f\ud83d\udc4f"
#                     },
#                     "updated": {
#                          "label": "2023-05-11T03:11:35-07:00"
#                     }
#                },
#                {
#                     "author": {
#                          "label": "",
#                          "name": {
#                               "label": "maxrgwhite"
#                          },
#                          "uri": {
#                               "label": "https://itunes.apple.com/gb/reviews/id524040326"
#                          }
#                     },
#                     "content": {
#                          "attributes": {
#                               "type": "text"
#                          },
#                          "label": "This app freely offers what multiple paid apps don\u2019t. It offers you quick access to your basic guide or self-administered (through a beginning and ending bell) meditation of selected length, as well as playlists and other resources for specific meditations (e.g. sleep or stress reduction). I love this app and have recommended it to many people. Thank you for helping me so profoundly!"
#                     },
#                     "id": {
#                          "label": "9769263685"
#                     },
#                     "im:contentType": {
#                          "attributes": {
#                               "label": "Application",
#                               "term": "Application"
#                          }
#                     },
#                     "im:rating": {
#                          "label": "5"
#                     },
#                     "im:version": {
#                          "label": "2.0.47"
#                     },
#                     "im:voteCount": {
#                          "label": "0"
#                     },
#                     "im:voteSum": {
#                          "label": "0"
#                     },
#                     "link": {
#                          "attributes": {
#                               "href": "https://itunes.apple.com/gb/review?id=1500780518&type=Purple%20Software",
#                               "rel": "related"
#                          }
#                     },
#                     "title": {
#                          "label": "Brilliant app!"
#                     },
#                     "updated": {
#                          "label": "2023-03-30T14:55:37-07:00"
#                     }
#                },
#                {
#                     "author": {
#                          "label": "",
#                          "name": {
#                               "label": "Sonny Paterson"
#                          },
#                          "uri": {
#                               "label": "https://itunes.apple.com/gb/reviews/id1130248109"
#                          }
#                     },
#                     "content": {
#                          "attributes": {
#                               "type": "text"
#                          },
#                          "label": "Great meditation app that really makes it easy to start. Would recommend."
#                     },
#                     "id": {
#                          "label": "9755356506"
#                     },
#                     "im:contentType": {
#                          "attributes": {
#                               "label": "Application",
#                               "term": "Application"
#                          }
#                     },
#                     "im:rating": {
#                          "label": "5"
#                     },
#                     "im:version": {
#                          "label": "2.0.47"
#                     },
#                     "im:voteCount": {
#                          "label": "0"
#                     },
#                     "im:voteSum": {
#                          "label": "0"
#                     },
#                     "link": {
#                          "attributes": {
#                               "href": "https://itunes.apple.com/gb/review?id=1500780518&type=Purple%20Software",
#                               "rel": "related"
#                          }
#                     },
#                     "title": {
#                          "label": "Very good app"
#                     },
#                     "updated": {
#                          "label": "2023-03-26T14:09:31-07:00"
#                     }
#                },
#                {
#                     "author": {
#                          "label": "",
#                          "name": {
#                               "label": "Tula Tina"
#                          },
#                          "uri": {
#                               "label": "https://itunes.apple.com/gb/reviews/id619303536"
#                          }
#                     },
#                     "content": {
#                          "attributes": {
#                               "type": "text"
#                          },
#                          "label": "So much to like. Love the different choices and how you can build up your practice to suit you. Being able to choose a different person/ voice to listen too is great.\nIt\u2019s not only simple to use but simple to understand so will suit everyone, so here comes the but \u2026. It has become increasingly difficult to get onto. Loading is a big problem. I have tried many times over four days but only managed to get on twice. A meditation app really shouldn\u2019t leave you frustrated."
#                     },
#                     "id": {
#                          "label": "9715099744"
#                     },
#                     "im:contentType": {
#                          "attributes": {
#                               "label": "Application",
#                               "term": "Application"
#                          }
#                     },
#                     "im:rating": {
#                          "label": "3"
#                     },
#                     "im:version": {
#                          "label": "2.0.47"
#                     },
#                     "im:voteCount": {
#                          "label": "0"
#                     },
#                     "im:voteSum": {
#                          "label": "0"
#                     },
#                     "link": {
#                          "attributes": {
#                               "href": "https://itunes.apple.com/gb/review?id=1500780518&type=Purple%20Software",
#                               "rel": "related"
#                          }
#                     },
#                     "title": {
#                          "label": "Love it and loath it."
#                     },
#                     "updated": {
#                          "label": "2023-03-15T01:37:12-07:00"
#                     }
#                },
#                {
#                     "author": {
#                          "label": "",
#                          "name": {
#                               "label": "gribes05"
#                          },
#                          "uri": {
#                               "label": "https://itunes.apple.com/gb/reviews/id457113235"
#                          }
#                     },
#                     "content": {
#                          "attributes": {
#                               "type": "text"
#                          },
#                          "label": "Medito is an amazing and 100% to use app. The mediation sessions are easy to get into and you get guided by the narrator very well. There are even courses included to improve your meditation experience."
#                     },
#                     "id": {
#                          "label": "9701405243"
#                     },
#                     "im:contentType": {
#                          "attributes": {
#                               "label": "Application",
#                               "term": "Application"
#                          }
#                     },
#                     "im:rating": {
#                          "label": "5"
#                     },
#                     "im:version": {
#                          "label": "2.0.47"
#                     },
#                     "im:voteCount": {
#                          "label": "1"
#                     },
#                     "im:voteSum": {
#                          "label": "0"
#                     },
#                     "link": {
#                          "attributes": {
#                               "href": "https://itunes.apple.com/gb/review?id=1500780518&type=Purple%20Software",
#                               "rel": "related"
#                          }
#                     },
#                     "title": {
#                          "label": "Could not recommend it more"
#                     },
#                     "updated": {
#                          "label": "2023-03-11T01:21:22-07:00"
#                     }
#                },
#                {
#                     "author": {
#                          "label": "",
#                          "name": {
#                               "label": "1736382649"
#                          },
#                          "uri": {
#                               "label": "https://itunes.apple.com/gb/reviews/id307820098"
#                          }
#                     },
#                     "content": {
#                          "attributes": {
#                               "type": "text"
#                          },
#                          "label": "A free app with helpful guidance from dedicated people. Thumb up!"
#                     },
#                     "id": {
#                          "label": "9628043528"
#                     },
#                     "im:contentType": {
#                          "attributes": {
#                               "label": "Application",
#                               "term": "Application"
#                          }
#                     },
#                     "im:rating": {
#                          "label": "5"
#                     },
#                     "im:version": {
#                          "label": "2.0.47"
#                     },
#                     "im:voteCount": {
#                          "label": "0"
#                     },
#                     "im:voteSum": {
#                          "label": "0"
#                     },
#                     "link": {
#                          "attributes": {
#                               "href": "https://itunes.apple.com/gb/review?id=1500780518&type=Purple%20Software",
#                               "rel": "related"
#                          }
#                     },
#                     "title": {
#                          "label": "Excellent"
#                     },
#                     "updated": {
#                          "label": "2023-02-17T14:34:28-07:00"
#                     }
#                }
#           ],
#           "icon": {
#                "label": "http://itunes.apple.com/favicon.ico"
#           },
#           "id": {
#                "label": "https://mzstoreservices-int-st.itunes.apple.com/gb/rss/customerreviews/id=1500780518/sortBy=mostRecent/json"
#           },
#           "link": [
#                {
#                     "attributes": {
#                          "href": "https://music.apple.com/WebObjects/MZStore.woa/wa/viewGrouping?cc=gb&id=130",
#                          "rel": "alternate",
#                          "type": "text/html"
#                     }
#                },
#                {
#                     "attributes": {
#                          "href": "https://mzstoreservices-int-st.itunes.apple.com/gb/rss/customerreviews/id=1500780518/sortBy=mostRecent/json",
#                          "rel": "self"
#                     }
#                },
#                {
#                     "attributes": {
#                          "href": "https://itunes.apple.com/gb/rss/customerreviews/page=1/id=1500780518/sortby=mostrecent/xml?urlDesc=/customerreviews/id=1500780518/sortBy=mostRecent/json",
#                          "rel": "first"
#                     }
#                },
#                {
#                     "attributes": {
#                          "href": "https://itunes.apple.com/gb/rss/customerreviews/page=4/id=1500780518/sortby=mostrecent/xml?urlDesc=/customerreviews/id=1500780518/sortBy=mostRecent/json",
#                          "rel": "last"
#                     }
#                },
#                {
#                     "attributes": {
#                          "href": "https://itunes.apple.com/gb/rss/customerreviews/page=1/id=1500780518/sortby=mostrecent/xml?urlDesc=/customerreviews/id=1500780518/sortBy=mostRecent/json",
#                          "rel": "previous"
#                     }
#                },
#                {
#                     "attributes": {
#                          "href": "https://itunes.apple.com/gb/rss/customerreviews/page=2/id=1500780518/sortby=mostrecent/xml?urlDesc=/customerreviews/id=1500780518/sortBy=mostRecent/json",
#                          "rel": "next"
#                     }
#                }
#           ],
#           "rights": {
#                "label": "Copyright 2008 Apple Inc."
#           },
#           "title": {
#                "label": "iTunes Store: Customer Reviews"
#           },
#           "updated": {
#                "label": "2024-02-18T23:16:26-07:00"
#           }
#      }
# }

# %%
# Save data to a json file locally
with open("json_data.json", "w") as file:
    json.dump(data, file)

# %%
# Read json file in python from local path
with open("json_data.json", "r") as file:
    data_file = json.load(file)

    print(data_file)
# Out:
# {'feed': {'author': {'name': {'label': 'iTunes Store'}, 'uri': {'label': 'http://www.apple.com/uk/itunes/'}}, 'entry': [{'author': {'uri': {'label': 'https://itunes.apple.com/gb/reviews/id1226434175'}, 'name': {'label': '_eddyne'}, 'label': ''}, 'updated': {'label': '2024-02-13T00:57:44-07:00'}, 'im:rating': {'label': '5'}, 'im:version': {'label': '3.0.13'}, 'id': {'label': '10933503223'}, 'title': {'label': 'Best meditation app'}, 'content': {'label': 'This app was recommended to me by hamza and it’s completely changed my life . Thank you Medito .', 'attributes': {'type': 'text'}}, 'link': {'attributes': {'rel': 'related', 'href': 'https://itunes.apple.com/gb/review?id=1500780518&type=Purple%20Software'}}, 'im:voteSum': {'label': '0'}, 'im:contentType': {'attributes': {'term': 'Application', 'label': 'Application'}}, 'im:voteCount': {'label': '0'}}, {'author': {'uri': {'label': 'https://itunes.apple.com/gb/reviews/id1196688209'}, 'name': {'label': 'KayFaraday69'}, 'label': ''}, 'updated': {'label': '2024-02-04T13:15:09-07:00'}, 'im:rating': {'label': '3'}, 'im:version': {'label': '3.0.13'}, 'id': {'label': '10902191584'}, 'title': {'label': 'Good but could be a lot better'}, 'content': {'label': 'I like the recordings themselves they are cool and the course is cool too but please the app feels so slow sometimes and please do a way to make an account because I lose all my progress and stats in the course when I have to uninstall and reinstall the app, so if you could do a way to back up the progress that would be wonderful', 'attributes': {'type': 'text'}}, 'link': {'attributes': {'rel': 'related', 'href': 'https://itunes.apple.com/gb/review?id=1500780518&type=Purple%20Software'}}, 'im:voteSum': {'label': '0'}, 'im:contentType': {'attributes': {'term': 'Application', 'label': 'Application'}}, 'im:voteCount': {'label': '0'}}, {'author': {'uri': {'label': 'https://itunes.apple.com/gb/reviews/id35697210'}, 'name': {'label': 'Jonathan-R'}, 'label': ''}, 'updated': {'label': '2024-01-29T14:26:09-07:00'}, 'im:rating': {'label': '1'}, 'im:version': {'label': '3.0.13'}, 'id': {'label': '10878856044'}, 'title': {'label': 'Seems promising but app doesn’t work'}, 'content': {'label': 'Intermittent “type” errors make the app completely unusable unfortunately.', 'attributes': {'type': 'text'}}, 'link': {'attributes': {'rel': 'related', 'href': 'https://itunes.apple.com/gb/review?id=1500780518&type=Purple%20Software'}}, 'im:voteSum': {'label': '0'}, 'im:contentType': {'attributes': {'term': 'Application', 'label': 'Application'}}, 'im:voteCount': {'label': '0'}}, {'author': {'uri': {'label': 'https://itunes.apple.com/gb/reviews/id110585716'}, 'name': {'label': 'bapanada'}, 'label': ''}, 'updated': {'label': '2024-01-18T16:02:49-07:00'}, 'im:rating': {'label': '3'}, 'im:version': {'label': '3.0.13'}, 'id': {'label': '10837489637'}, 'title': {'label': 'Great resource, shame about the AI images'}, 'content': {'label': 'I previously left a 5-star rating because I have found Medito to be an excellent app and resource, and I am so thankful that it is ad-free and doesn’t harvest my data. I use it every day and am on a nearly 800-day streak at this point. However, with the recent UI update, I am really disappointed that the team decided to change from the previous simple, consistent artwork to a bunch of AI images. They are obviously modelled after a particular artist’s work in an attempt to look consistent, and I highly doubt that artist was consulted or compensated for this unethical scraping of their work. Additionally, I find many of the images deeply unsettling and disturbing to look at: the opposite of what a meditation app should do! I have found myself more and more reluctant to open up the app because of this, and I’m really sad about that. I hope the Medito team will consider commissioning some art from a human being soon.', 'attributes': {'type': 'text'}}, 'link': {'attributes': {'rel': 'related', 'href': 'https://itunes.apple.com/gb/rev ...

# %% [markdown]
# ### Cleaning this json data

# %%
entries = data["feed"]["entry"]
entries[0]
# Out:
# {'author': {'uri': {'label': 'https://itunes.apple.com/gb/reviews/id1226434175'},
#   'name': {'label': '_eddyne'},
#   'label': ''},
#  'updated': {'label': '2024-02-13T00:57:44-07:00'},
#  'im:rating': {'label': '5'},
#  'im:version': {'label': '3.0.13'},
#  'id': {'label': '10933503223'},
#  'title': {'label': 'Best meditation app'},
#  'content': {'label': 'This app was recommended to me by hamza and it’s completely changed my life . Thank you Medito .',
#   'attributes': {'type': 'text'}},
#  'link': {'attributes': {'rel': 'related',
#    'href': 'https://itunes.apple.com/gb/review?id=1500780518&type=Purple%20Software'}},
#  'im:voteSum': {'label': '0'},
#  'im:contentType': {'attributes': {'term': 'Application',
#    'label': 'Application'}},
#  'im:voteCount': {'label': '0'}}

# %%
entries[0].keys()
# Out:
# dict_keys(['author', 'updated', 'im:rating', 'im:version', 'id', 'title', 'content', 'link', 'im:voteSum', 'im:contentType', 'im:voteCount'])

# %%
entries[0]['author']
# Out:
# {'uri': {'label': 'https://itunes.apple.com/gb/reviews/id1226434175'},
#  'name': {'label': '_eddyne'},
#  'label': ''}

# %%
author_uri_list = []
author_name_list = []

for item in entries:
    author_uri_list.append(list(item.get('author')['uri'].values())[0])
    author_name_list.append(list(item.get('author')['name'].values())[0])

author_uri_dict = {'author_uri' : author_uri_list }
author_name_dict = {'author_name' : author_name_list }

print(author_uri_dict, author_name_dict)
# Out:
# {'author_uri': ['https://itunes.apple.com/gb/reviews/id1226434175', 'https://itunes.apple.com/gb/reviews/id1196688209', 'https://itunes.apple.com/gb/reviews/id35697210', 'https://itunes.apple.com/gb/reviews/id110585716', 'https://itunes.apple.com/gb/reviews/id967020663', 'https://itunes.apple.com/gb/reviews/id824093642', 'https://itunes.apple.com/gb/reviews/id1226425216', 'https://itunes.apple.com/gb/reviews/id580563869', 'https://itunes.apple.com/gb/reviews/id750327845', 'https://itunes.apple.com/gb/reviews/id537801546', 'https://itunes.apple.com/gb/reviews/id641668833', 'https://itunes.apple.com/gb/reviews/id1054235828', 'https://itunes.apple.com/gb/reviews/id1297206556', 'https://itunes.apple.com/gb/reviews/id758237746', 'https://itunes.apple.com/gb/reviews/id1242075443', 'https://itunes.apple.com/gb/reviews/id1475476224', 'https://itunes.apple.com/gb/reviews/id601846694', 'https://itunes.apple.com/gb/reviews/id577881795', 'https://itunes.apple.com/gb/reviews/id1309296731', 'https://itunes.apple.com/gb/reviews/id1444600231', 'https://itunes.apple.com/gb/reviews/id1282646886', 'https://itunes.apple.com/gb/reviews/id178350449', 'https://itunes.apple.com/gb/reviews/id634027578', 'https://itunes.apple.com/gb/reviews/id1409860751', 'https://itunes.apple.com/gb/reviews/id389442069', 'https://itunes.apple.com/gb/reviews/id1590178266', 'https://itunes.apple.com/gb/reviews/id1356455290', 'https://itunes.apple.com/gb/reviews/id1263945402', 'https://itunes.apple.com/gb/reviews/id353324833', 'https://itunes.apple.com/gb/reviews/id124403543', 'https://itunes.apple.com/gb/reviews/id774947242', 'https://itunes.apple.com/gb/reviews/id190638990', 'https://itunes.apple.com/gb/reviews/id1246655147', 'https://itunes.apple.com/gb/reviews/id220248664', 'https://itunes.apple.com/gb/reviews/id931857852', 'https://itunes.apple.com/gb/reviews/id1443895080', 'https://itunes.apple.com/gb/reviews/id1515744207', 'https://itunes.apple.com/gb/reviews/id1550436557', 'https://itunes.apple.com/gb/reviews/id1187633718', 'https://itunes.apple.com/gb/reviews/id325372246', 'https://itunes.apple.com/gb/reviews/id1450308419', 'https://itunes.apple.com/gb/reviews/id896220515', 'https://itunes.apple.com/gb/reviews/id316335028', 'https://itunes.apple.com/gb/reviews/id953046066', 'https://itunes.apple.com/gb/reviews/id380922049', 'https://itunes.apple.com/gb/reviews/id524040326', 'https://itunes.apple.com/gb/reviews/id1130248109', 'https://itunes.apple.com/gb/reviews/id619303536', 'https://itunes.apple.com/gb/reviews/id457113235', 'https://itunes.apple.com/gb/reviews/id307820098']} {'author_name': ['_eddyne', 'KayFaraday69', 'Jonathan-R', 'bapanada', 'Adithebaddie.', 'Joel🌻', 'Adam Elharrati', 'Adrian0001928', 'Baggs00', 'C.Breezy19', 'Mxpze', 'TonyDaBoss123', 'MihaiTeo', 'nshshshhshahhs', '93@/)3@/£:7;£38,:)/&/,.,.?', 'steven009282', 'Katya_%', 'heloo mate', 'kslhawkem', 'txmmzy', 'TSAgscasfz', 'AshishJoshi1965', 'UnicornFlosser_451', 'Adonisssssssssssssssssssss', 'Trevor Lyons', 'Mazzer50', 'Siymone', 'lilffx', 'C00ki3 SAAN', 'Happier By The Day', 'Tonyafc32', 'Suicidal132', 'YusukeT915', 'Wondermonkeyda', 'Alakarem', 'OwenGrady2003', 'Ed Keen', 'Michael medito13', 'JoaquinMiggle', 'bethjonessxo', 'Limitless Lion', 'WolfSister3', 'Eugenikus', 'JackM1359', 'Oligog', 'maxrgwhite', 'Sonny Paterson', 'Tula Tina', 'gribes05', '1736382649']}

# %% [markdown]
# ## Tips:
# You can use `?` or `help()` to get help in python

# %%
?

# %%
help('math')

# %% [markdown]
# ### Install OpenAI packages and upgrade to the most up-to-date one

# %%
# !pip3 install openai
# !pip3 install --upgrade openai

# !pip3 show openai | grep Version
# Out:
# Collecting openai
#   Downloading openai-1.12.0-py3-none-any.whl (226 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 226.7/226.7 kB 2.5 MB/s eta 0:00:00
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from openai) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from openai) (1.7.0)
# Collecting httpx<1,>=0.23.0 (from openai)
#   Downloading httpx-0.26.0-py3-none-any.whl (75 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.9/75.9 kB 12.1 MB/s eta 0:00:00
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from openai) (2.6.1)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from openai) (1.3.0)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.10/dist-packages (from openai) (4.66.2)
# Requirement already satisfied: typing-extensions<5,>=4.7 in /usr/local/lib/python3.10/dist-packages (from openai) (4.9.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai) (3.6)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai) (1.2.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai) (2024.2.2)
# Collecting httpcore==1.* (from httpx<1,>=0.23.0->openai)
#   Downloading httpcore-1.0.3-py3-none-any.whl (77 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.0/77.0 kB 11.3 MB/s eta 0:00:00
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx<1,>=0.23.0->openai)
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 7.2 MB/s eta 0:00:00
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.2 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai) (2.16.2)
# Installing collected packages: h11, httpcore, httpx, openai
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# llmx 0.0.15a0 requires cohere, which is not installed.
# llmx 0.0.15a0 requires tiktoken, which is not installed.
# Successfully installed h11-0.14.0 httpcore-1.0.3 httpx-0.26.0 openai-1.12.0
# Requirement already satisfied: openai in /usr/local/lib/python3.10/dist-packages (1.12.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from openai) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from openai) (1.7.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from openai) (0.26.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from openai) (2.6.1)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from openai) (1.3.0)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.10/dist-packages (from openai) (4.66.2)
# Requirement already satisfied: typing-extensions<5,>=4.7 in /usr/local/lib/python3.10/dist-packages (from openai) (4.9.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai) (3.6)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai) (1.2.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai) (2024.2.2)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai) (1.0.3)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.14.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.2 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai) (2.16.2)
# Version: 1.12.0

# %% [markdown]
# ### Make sure you've generate an API KEY. If not, use this [LINK](https://platform.openai.com/playground)

# %%
# Initialize the OpenAI client with your API key
import os
from openai import OpenAI

API_KEY = "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"

client = OpenAI(api_key = API_KEY)

# %% [markdown]
# # 1. Code Interpreter
# Code Interpreter allows the Assistants API to write and run Python code in a sandboxed execution environment. This tool can process files with diverse data and formatting, and generate files with data and images of graphs. Code Interpreter allows your Assistant to run code iteratively to solve challenging code and math problems. When your Assistant writes code that fails to run, it can iterate on this code by attempting to run different code until the code execution succeeds.

# %% [markdown]
# ## Step 1: Create OpenAI Assistant

# %%
assistant = client.beta.assistants.create(
    name = "Math Tutor",
    instructions = "You are a personal math tutor. Answer questions briefly, in a sentence or less.",
    tools = [{"type": "code_interpreter"}],
    model = "gpt-3.5-turbo-1106"
)

# %% [markdown]
# ## Step 2: Create a Thread

# %%
thread = client.beta.threads.create()
print(thread)
# Out:
# Thread(id='thread_gEOOwiGaJHEO9wSJI1RBpKmt', created_at=1708327135, metadata={}, object='thread', tool_resources=[])

# %% [markdown]
# ## Step 3: Add a Message to a Thread

# %%
message = client.beta.threads.messages.create(
  thread_id = thread.id,
  role = "user",
  content = "Mary, Peter, and Lucy were picking chestnuts. Mary picked twice as much chestnuts than Peter. Lucy picked 2 kg more than Peter. Together the three of them picked 26 kg of chestnuts. How many kilograms did each of them pick?"
  # "Solve this problem: 3x + 11 = 14 ."
  # "What is the result of 78 / 60 ? "
)

print(message)
# Out:
# ThreadMessage(id='msg_ujj75qboinUhzOzsn5Ce5TAI', assistant_id=None, content=[MessageContentText(text=Text(annotations=[], value='Mary, Peter, and Lucy were picking chestnuts. Mary picked twice as much chestnuts than Peter. Lucy picked 2 kg more than Peter. Together the three of them picked 26 kg of chestnuts. How many kilograms did each of them pick?'), type='text')], created_at=1708327145, file_ids=[], metadata={}, object='thread.message', role='user', run_id=None, thread_id='thread_gEOOwiGaJHEO9wSJI1RBpKmt')

# %% [markdown]
# ## Step 4: Run the Assistant

# %%
run = client.beta.threads.runs.create(
    thread_id = thread.id,
    assistant_id = assistant.id
)

# %% [markdown]
# ## Step 5: Display the Assistant's Response

# %%
run = client.beta.threads.runs.retrieve(
    thread_id = thread.id,
    run_id = run.id
)

# %%
messages = client.beta.threads.messages.list(
    thread_id = thread.id
)

# %%
## reversed -- get the most old messages first
for message in reversed(messages.data):
    print(message.role + ": " + message.content[0].text.value)
# Out:
# user: Mary, Peter, and Lucy were picking chestnuts. Mary picked twice as much chestnuts than Peter. Lucy picked 2 kg more than Peter. Together the three of them picked 26 kg of chestnuts. How many kilograms did each of them pick?

# %% [markdown]
# # 2. Knowledge Retrieval
# Retrieval augments the Assistant with knowledge from outside its model, such as proprietary product information or documents provided by your users. Once a file is uploaded and passed to the Assistant, OpenAI will automatically chunk your documents, index and store the embeddings, and implement vector search to retrieve relevant content to answer user queries.

# %% [markdown]
# ## Upload Files to OpenAI

# %%
file = client.files.create(
    file = open("avalon.txt", "rb"),
    purpose = "assistants"
)

print(file)
# Out:
# FileObject(id='file-YHFZPSZuSNJIxkrhSlKVZ4vj', bytes=5318, created_at=1708327329, filename='avalon.txt', object='file', purpose='assistants', status='processed', status_details=None)

# %% [markdown]
# ## Delete a file
#
# ```
# file_deletion_status = client.beta.assistants.files.delete(
#   assistant_id=assistant.id,
#   file_id=file.id
# )
#
# ```

# %% [markdown]
# ## Create the Assistant

# %%
assistant = client.beta.assistants.create(
    name = "Avalon Rules",
    instructions = "Teach people how to play Avalon.",
    tools = [{"type": "retrieval"}],
    model = "gpt-3.5-turbo-1106",
    file_ids = [file.id]
)

# %% [markdown]
# ## Create a thread

# %%
thread = client.beta.threads.create()
print(thread)
# Out:
# Thread(id='thread_4cMe5xgOYnrDpBrYo5nPHvIl', created_at=1708327468, metadata={}, object='thread', tool_resources=[])

# %% [markdown]
# ## Create a message

# %%
message = client.beta.threads.messages.create(
  thread_id = thread.id,
  role = "user",
  content = "How many teams in the Avalon?"
  # "What does Merlin do?"
)

print(message)
# Out:
# ThreadMessage(id='msg_6jqkTWnphB9WvpaTlaUSR2xj', assistant_id=None, content=[MessageContentText(text=Text(annotations=[], value='How many teams in the Avalon?'), type='text')], created_at=1708327470, file_ids=[], metadata={}, object='thread.message', role='user', run_id=None, thread_id='thread_4cMe5xgOYnrDpBrYo5nPHvIl')

# %% [markdown]
# ## Run the assistant

# %%
run = client.beta.threads.runs.create(
    thread_id = thread.id,
    assistant_id = assistant.id
)

# %% [markdown]
# ## Display the Assistant's Response

# %%
run = client.beta.threads.runs.retrieve(
    thread_id = thread.id,
    run_id = run.id
)

# %%
messages = client.beta.threads.messages.list(
    thread_id = thread.id
)

# %%
## reversed -- get the most old messages first
for message in reversed(messages.data):
    print(message.role + ": " + message.content[0].text.value)
# Out:
# user: How many teams in the Avalon?
# assistant: In Avalon, the number of teams can vary depending on the number of players involved. For a 6-player game, there are "Minions of Mordred" (Evil players) and "Loyal Servants of Arthur" (Good players), which includes Merlin and 3 other Good players【7†source】. The game board and the corresponding roles are adjusted based on the number of players involved. Therefore, the number of teams can change based on the specific setup of the game.
